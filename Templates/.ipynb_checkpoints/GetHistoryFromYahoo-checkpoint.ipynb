# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
pf.create_returns_tear_sheet(df_sreturns.SReturns, live_start_date='2018-1-1')
# Out:
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\empyrical\stats.py:445: RuntimeWarning: invalid value encountered in double_scalars
#   return ending_value ** (1 / num_years) - 1
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\empyrical\stats.py:1492: RuntimeWarning: invalid value encountered in log1p
#   cum_log_returns = np.log1p(returns).cumsum()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-116accb0b95f> in <module>
# ----> 1 pf.create_returns_tear_sheet(df_sreturns.SReturns, live_start_date='2018-1-1')
#
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pyfolio\plotting.py in call_w_context(*args, **kwargs)
#      50         if set_context:
#      51             with plotting_context(), axes_style():
# ---> 52                 return func(*args, **kwargs)
#      53         else:
#      54             return func(*args, **kwargs)
#
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pyfolio\tears.py in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     494         returns = utils.clip_returns_to_benchmark(returns, benchmark_rets)
#     495
# --> 496     plotting.show_perf_stats(returns, benchmark_rets,
#     497                              positions=positions,
#     498                              transactions=transactions,
#
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pyfolio\plotting.py in show_perf_stats(returns, factor_returns, positions, transactions, turnover_denom, live_start_date, bootstrap, header_rows)
#     598     if live_start_date is not None:
#     599         live_start_date = ep.utils.get_utc_timestamp(live_start_date)
# --> 600         returns_is = returns[returns.index < live_start_date]
#     601         returns_oos = returns[returns.index >= live_start_date]
#     602
#
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\extension.py in wrapper(self, other)
#     127
#     128         op = getattr(self._data, opname)
# --> 129         return op(other)
#     130
#     131     wrapper.__name__ = opname
#
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\arrays\datetimelike.py in wrapper(self, other)
#     114
#     115         try:
# --> 116             other = _validate_comparison_value(self, other)
#     117         except InvalidComparison:
#     118             return invalid_comparison(self, other, op)
#
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\arrays\datetimelike.py in _validate_comparison_value(self, other)
#      91         if isinstance(other, self._recognized_scalars) or other is NaT:
#      92             other = self._scalar_type(other)
# ---> 93             self._check_compatible_with(other)
#      94
#      95         elif not is_list_like(other):
#
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\arrays\datetimes.py in _check_compatible_with(self, other, setitem)
#     460         if other is NaT:
#     461             return
# --> 462         self._assert_tzawareness_compat(other)
#     463         if setitem:
#     464             # Stricter check for setitem vs comparison methods
#
# c:\users\vishwanath.vidap\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\arrays\datetimes.py in _assert_tzawareness_compat(self, other)
#     639         elif self.tz is None:
#     640             if other_tz is not None:
# --> 641                 raise TypeError(
#     642                     "Cannot compare tz-naive and tz-aware datetime-like objects."
#     643                 )
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects.
