# %%
class TickData(object):
	""" Stores a single unit of data """

	def __init__(self, timestamp='', symbol='',
				open_price=0, close_price=0, total_volume=0):
		self.symbol = symbol
		self.timestamp = timestamp
		self.open_price = open_price
		self.close_price = close_price
		self.total_volume = total_volume

# %%
class MarketData(object):
	def __init__(self):
		self.recent_ticks = dict()  # indexed by symbol

	def add_tick_data(self, tick_data):
		self.recent_ticks[tick_data.symbol] = tick_data

	def get_open_price(self, symbol):
		return self.get_tick_data(symbol).open_price

	def get_close_price(self, symbol):
		return self.get_tick_data(symbol).close_price

	def get_tick_data(self, symbol):
		return self.recent_ticks.get(symbol, TickData())

	def get_timestamp(self, symbol):
		return self.recent_ticks[symbol].timestamp

# %%
class MarketDataSource(object):
    def __init__(self, symbol, tick_event_handler=None, start='', end=''):
        self.market_data = MarketData()

        self.symbol = symbol
        self.tick_event_handler = tick_event_handler
        self.start, self.end = start, end
        self.df = None

    def fetch_historical_prices(self):
        import pandas_datareader as web
        df = web.DataReader(self.symbol, 'yahoo', self.start, self.end)
        return df

    def run(self):
        if self.df is None:
            self.df = self.fetch_historical_prices()

        total_ticks = len(self.df)
        print('Processing total_ticks:', total_ticks)

        for timestamp, row in self.df.iterrows():
            open_price = row['Open']
            close_price = row['Close']
            volume = row['Volume']

            print(timestamp.date(), 'TICK', self.symbol,
                  'open:', open_price,
                  'close:', close_price)
            tick_data = TickData(timestamp, self.symbol, open_price,
                                close_price, volume)
            self.market_data.add_tick_data(tick_data)

            if self.tick_event_handler:
                self.tick_event_handler(self.market_data)

# %%
class Order(object):
	def __init__(self, timestamp, symbol, 
		qty, is_buy, is_market_order, 
		price=0
	):
		self.timestamp = timestamp
		self.symbol = symbol
		self.qty = qty
		self.price = price
		self.is_buy = is_buy
		self.is_market_order = is_market_order
		self.is_filled = False
		self.filled_price = 0
		self.filled_time = None
		self.filled_qty = 0

# %%
class Position(object):
	def __init__(self, symbol=''):
		self.symbol = symbol
		self.buys = self.sells = self.net = 0
		self.rpnl = 0
		self.position_value = 0

	def on_position_event(self, is_buy, qty, price):
		if is_buy:
			self.buys += qty
		else:
			self.sells += qty

		self.net = self.buys - self.sells
		changed_value = qty * price * (-1 if is_buy else 1)
		self.position_value += changed_value

		if self.net == 0:
			self.rpnl = self.position_value
			self.position_value = 0

	def calculate_unrealized_pnl(self, price):
		if self.net == 0:
			return 0

		market_value = self.net * price
		upnl = self.position_value + market_value
		return upnl

# %%
from abc import abstractmethod

class Strategy:
	def __init__(self, send_order_event_handler):
		self.send_order_event_handler = send_order_event_handler

	@abstractmethod
	def on_tick_event(self, market_data):
		raise NotImplementedError('Method is required!')

	@abstractmethod
	def on_position_event(self, positions):
		raise NotImplementedError('Method is required!')

	def send_market_order(self, symbol, qty, is_buy, timestamp):
		if self.send_order_event_handler:
			order = Order(
				timestamp,
				symbol,
				qty,
				is_buy,
				is_market_order=True,
				price=0,
			)
			self.send_order_event_handler(order)

# %%
import pandas as pd

class MeanRevertingStrategy(Strategy):
    def __init__(self, symbol, trade_qty,
        send_order_event_handler=None, lookback_intervals=20,
        buy_threshold=-1.5, sell_threshold=1.5
    ):
        super(MeanRevertingStrategy, self).__init__(
            send_order_event_handler)

        self.symbol = symbol
        self.trade_qty = trade_qty
        self.lookback_intervals = lookback_intervals
        self.buy_threshold = buy_threshold
        self.sell_threshold = sell_threshold

        self.prices = pd.DataFrame()
        self.is_long = self.is_short = False

    def on_position_event(self, positions):
        position = positions.get(self.symbol)

        self.is_long = position and position.net > 0
        self.is_short = position and position.net < 0

    def on_tick_event(self, market_data):
        self.store_prices(market_data)

        if len(self.prices) < self.lookback_intervals:
            return

        self.generate_signals_and_send_order(market_data)

    def store_prices(self, market_data):
        timestamp = market_data.get_timestamp(self.symbol)
        close_price = market_data.get_close_price(self.symbol)
        self.prices.loc[timestamp, 'close'] = close_price

    def generate_signals_and_send_order(self, market_data):
        signal_value = self.calculate_z_score()
        timestamp = market_data.get_timestamp(self.symbol)

        if self.buy_threshold > signal_value and not self.is_long:
            print(timestamp.date(), 'BUY signal')
            self.send_market_order(
                self.symbol, self.trade_qty, True, timestamp)
        elif self.sell_threshold < signal_value and not self.is_short:
            print(timestamp.date(), 'SELL signal')
            self.send_market_order(
                self.symbol, self.trade_qty, False, timestamp)

    def calculate_z_score(self):
        self.prices = self.prices[-self.lookback_intervals:]
        returns = self.prices['close'].pct_change().dropna()
        z_score = ((returns - returns.mean()) / returns.std())[-1]
        return z_score

# %%
class BacktestEngine:
	def __init__(self, symbol, trade_qty, start='', end=''):
		self.symbol = symbol
		self.trade_qty = trade_qty
		self.market_data_source = MarketDataSource(
			symbol,
			tick_event_handler=self.on_tick_event,
			start=start, end=end
		)

		self.strategy = None
		self.unfilled_orders = []
		self.positions = dict()
		self.df_rpnl = None
        
	def start(self, **kwargs):
		print('Backtest started...')

		self.unfilled_orders = []
		self.positions = dict()
		self.df_rpnl = pd.DataFrame()

		self.strategy = MeanRevertingStrategy(
			self.symbol,
			self.trade_qty,
			send_order_event_handler=self.on_order_received,
			**kwargs
		)
		self.market_data_source.run()

		print('Backtest completed.')
        
	def on_order_received(self, order):
		""" Adds an order to the order book """
		print(
			order.timestamp.date(),
			'ORDER',
			'BUY' if order.is_buy else 'SELL',
			order.symbol,
			order.qty
		)
		self.unfilled_orders.append(order)
        
	def on_tick_event(self, market_data):
		self.match_order_book(market_data)
		self.strategy.on_tick_event(market_data)
		self.print_position_status(market_data)
        
	def match_order_book(self, market_data):
		if len(self.unfilled_orders) > 0:
			self.unfilled_orders = [
				order for order in self.unfilled_orders
				if self.match_unfilled_orders(order, market_data)
			]
            
	def match_unfilled_orders(self, order, market_data):
		symbol = order.symbol
		timestamp = market_data.get_timestamp(symbol)

		""" Order is matched and filled """
		if order.is_market_order and timestamp > order.timestamp:
			open_price = market_data.get_open_price(symbol)

			order.is_filled = True
			order.filled_timestamp = timestamp
			order.filled_price = open_price

			self.on_order_filled(
				symbol, order.qty, order.is_buy,
				open_price, timestamp
			)
			return False

		return True
    
	def on_order_filled(self, symbol, qty, is_buy, filled_price, timestamp):
		position = self.get_position(symbol)
		position.on_position_event(is_buy, qty, filled_price)
		self.df_rpnl.loc[timestamp, "rpnl"] = position.rpnl

		self.strategy.on_position_event(self.positions)

		print(
			timestamp.date(),
			'FILLED', "BUY" if is_buy else "SELL",
			qty, symbol, 'at', filled_price
		)
        
	def get_position(self, symbol):
		if symbol not in self.positions:
			self.positions[symbol] = Position(symbol)

		return self.positions[symbol]
    
	def print_position_status(self, market_data):
		for symbol, position in self.positions.items():
			close_price = market_data.get_close_price(symbol)
			timestamp = market_data.get_timestamp(symbol)

			upnl = position.calculate_unrealized_pnl(close_price)

			print(
				timestamp.date(),
				'POSITION',
				'value:%.3f' % position.position_value,
				'upnl:%.3f' % upnl,
				'rpnl:%.3f' % position.rpnl
			)

# %%
engine = BacktestEngine(
    'ACC.NS', 1,
    start='2015-01-01',
    end='2017-12-31'
)

# %%
engine.start(
    lookback_intervals=20,
    buy_threshold=-1.5,
    sell_threshold=1.5
)
# Out:
# Backtest started...
# Processing total_ticks: 740
# 2015-01-01 TICK ACC.NS open: 1400.1500244140625 close: 1403.550048828125
# 2015-01-02 TICK ACC.NS open: 1406.4000244140625 close: 1425.9000244140625
# 2015-01-05 TICK ACC.NS open: 1425.0 close: 1433.6500244140625
# 2015-01-06 TICK ACC.NS open: 1425.0 close: 1383.550048828125
# 2015-01-07 TICK ACC.NS open: 1382.0 close: 1367.449951171875
# 2015-01-08 TICK ACC.NS open: 1378.0 close: 1391.4000244140625
# 2015-01-09 TICK ACC.NS open: 1397.800048828125 close: 1398.5
# 2015-01-12 TICK ACC.NS open: 1400.0 close: 1404.5999755859375
# 2015-01-13 TICK ACC.NS open: 1411.4000244140625 close: 1441.699951171875
# 2015-01-14 TICK ACC.NS open: 1448.0 close: 1478.3499755859375
# 2015-01-15 TICK ACC.NS open: 1496.5 close: 1514.4000244140625
# 2015-01-16 TICK ACC.NS open: 1514.5 close: 1518.3499755859375
# 2015-01-19 TICK ACC.NS open: 1521.9000244140625 close: 1532.9000244140625
# 2015-01-20 TICK ACC.NS open: 1534.550048828125 close: 1544.300048828125
# 2015-01-21 TICK ACC.NS open: 1548.0 close: 1544.449951171875
# 2015-01-22 TICK ACC.NS open: 1544.0 close: 1558.800048828125
# 2015-01-23 TICK ACC.NS open: 1569.0 close: 1542.050048828125
# 2015-01-27 TICK ACC.NS open: 1540.1500244140625 close: 1528.699951171875
# 2015-01-28 TICK ACC.NS open: 1527.449951171875 close: 1543.800048828125
# 2015-01-29 TICK ACC.NS open: 1544.9000244140625 close: 1582.949951171875
# 2015-01-30 TICK ACC.NS open: 1595.0 close: 1560.449951171875
# 2015-02-02 TICK ACC.NS open: 1554.9000244140625 close: 1524.949951171875
# 2015-02-02 BUY signal
# 2015-02-02 ORDER BUY ACC.NS 1
# 2015-02-03 TICK ACC.NS open: 1529.699951171875 close: 1508.5999755859375
# 2015-02-03 FILLED BUY 1 ACC.NS at 1529.699951171875
# 2015-02-03 POSITION value:-1529.700 upnl:-21.100 rpnl:0.000
# 2015-02-04 TICK ACC.NS open: 1511.949951171875 close: 1495.8499755859375
# 2015-02-04 POSITION value:-1529.700 upnl:-33.850 rpnl:0.000
# 2015-02-05 TICK ACC.NS open: 1494.0 close: 1504.550048828125
# 2015-02-05 POSITION value:-1529.700 upnl:-25.150 rpnl:0.000
# 2015-02-06 TICK ACC.NS open: 1503.0 close: 1507.199951171875
# 2015-02-06 POSITION value:-1529.700 upnl:-22.500 rpnl:0.000
# 2015-02-09 TICK ACC.NS open: 1501.449951171875 close: 1508.8499755859375
# 2015-02-09 POSITION value:-1529.700 upnl:-20.850 rpnl:0.000
# 2015-02-10 TICK ACC.NS open: 1502.9000244140625 close: 1562.6500244140625
# 2015-02-10 SELL signal
# 2015-02-10 ORDER SELL ACC.NS 1
# 2015-02-10 POSITION value:-1529.700 upnl:32.950 rpnl:0.000
# 2015-02-11 TICK ACC.NS open: 1567.0 close: 1552.5999755859375
# 2015-02-11 FILLED SELL 1 ACC.NS at 1567.0
# 2015-02-11 POSITION value:0.000 upnl:0.000 rpnl:37.300
# 2015-02-12 TICK ACC.NS open: 1567.449951171875 close: 1595.199951171875
# 2015-02-12 SELL signal
# 2015-02-12 ORDER SELL ACC.NS 1
# 2015-02-12 POSITION value:0.000 upnl:0.000 rpnl:37.300
# 2015-02-13 TICK ACC.NS open: 1608.0 close: 1625.050048828125
# 2015-02-13 FILLED SELL 1 ACC.NS at 1608.0
# 2015-02-13 POSITION value:1608.000 upnl:-17.050 rpnl:37.300
# 2015-02-16 TICK ACC.NS open: 1632.4000244140625 close: 1614.449951171875
# 2015-02-16 POSITION value:1608.000 upnl:-6.450 rpnl:37.300
# 2015-02-18 TICK ACC.NS open: 1614.699951171875 close: 1653.300048828125
# 2015-02-18 POSITION value:1608.000 upnl:-45.300 rpnl:37.300
# 2015-02-19 TICK ACC.NS open: 1662.4000244140625 close: 1615.1500244140625
# 2015-02-19 POSITION value:1608.000 upnl:-7.150 rpnl:37.300
# 2015-02-20 TICK ACC.NS open: 1623.4000244140625 close: 1620.4000244140625
# 2015-02-20 POSITION value:1608.000 upnl:-12.400 rpnl:37.300
# 2015-02-23 TICK ACC.NS open: 1628.0 close: 1615.949951171875
# 2015-02-23 POSITION value:1608.000 upnl:-7.950 rpnl:37.300
# 2015-02-24 TICK ACC.NS open: 1617.800048828125 close: 1618.0
# 2015-02-24 POSITION value:1608.000 upnl:-10.000 rpnl:37.300
# 2015-02-25 TICK ACC.NS open: 1626.199951171875 close: 1655.75
# 2015-02-25 POSITION value:1608.000 upnl:-47.750 rpnl:37.300
# 2015-02-26 TICK ACC.NS open: 1658.0999755859375 close: 1639.9000244140625
# 2015-02-26 POSITION value:1608.000 upnl:-31.900 rpnl:37.300
# 2015-02-27 TICK ACC.NS open: 1648.0 close: 1673.449951171875
# 2015-02-27 POSITION value:1608.000 upnl:-65.450 rpnl:37.300
# 2015-03-02 TICK ACC.NS open: 1680.0 close: 1762.800048828125
# 2015-03-02 POSITION value:1608.000 upnl:-154.800 rpnl:37.300
# 2015-03-03 TICK ACC.NS open: 1764.0 close: 1758.300048828125
# 2015-03-03 POSITION value:1608.000 upnl:-150.300 rpnl:37.300
# 2015-03-04 TICK ACC.NS open: 1765.0 close: 1725.1500244140625
# 2015-03-04 POSITION value:1608.000 upnl:-117.150 rpnl:37.300
# 2015-03-05 TICK ACC.NS open: 1725.5999755859375 close: 1698.6500244140625
# 2015-03-05 POSITION value:1608.000 upnl:-90.650 rpnl:37.300
# 2015-03-09 TICK ACC.NS open: 1686.0 close: 1660.0999755859375
# 2015-03-09 POSITION value:1608.000 upnl:-52.100 rpnl:37.300
# 2015-03-10 TICK ACC.NS open: 1661.0 close: 1650.1500244140625
# 2015-03-10 POSITION value:1608.000 upnl:-42.150 rpnl:37.300
# 2015-03-11 TICK ACC.NS open: 1650.0 close: 1639.699951171875
# 2015-03-11 POSITION value:1608.000 upnl:-31.700 rpnl:37.300
# 2015-03-12 TICK ACC.NS open: 1626.800048828125 close: 1648.0
# 2015-03-12 POSITION value:1608.000 upnl:-40.000 rpnl:37.300
# 2015-03-13 TICK ACC.NS open: 1658.9000244140625 close: 1616.0
# 2015-03-13 POSITION value:1608.000 upnl:-8.000 rpnl:37.300
# 2015-03-16 TICK ACC.NS open: 1621.0 close: 1587.550048828125
# 2015-03-16 POSITION value:1608.000 upnl:20.450 rpnl:37.300
# 2015-03-17 TICK ACC.NS open: 1591.050048828125 close: 1613.0
# 2015-03-17 POSITION value:1608.000 upnl:-5.000 rpnl:37.300
# 2015-03-18 TICK ACC.NS open: 1622.0 close: 1583.3499755859375
# 2015-03-18 POSITION value:1608.000 upnl:24.650 rpnl:37.300
# 2015-03-19 TICK ACC.NS open: 1592.4000244140625 close: 1568.5
# 2015-03-19 POSITION value:1608.000 upnl:39.500 rpnl:37.300
# 2015-03-20 TICK ACC.NS open: 1572.4000244140625 close: 1569.75
# 2015-03-20 POSITION value:1608.000 upnl:38.250 rpnl:37.300
# 2015-03-23 TICK ACC.NS open: 1570.5 close: 1586.75
# 2015-03-23 POSITION value:1608.000 upnl:21.250 rpnl:37.300
# 2015-03-24 TICK ACC.NS open: 1585.0 close: 1583.050048828125
# 2015-03-24 POSITION value:1608.000 upnl:24.950 rpnl:37.300
# 2015-03-25 TICK ACC.NS open: 1589.9000244140625 close: 1581.699951171875
# 2015-03-25 POSITION value:1608.000 upnl:26.300 rpnl:37.300
# 2015-03-26 TICK ACC.NS open: 1565.5 close: 1579.550048828125
# 2015-03-26 POSITION value:1608.000 upnl:28.450 rpnl:37.300
# 2015-03-27 TICK ACC.NS open: 1585.25 close: 1549.449951171875
# 2015-03-27 POSITION value:1608.000 upnl:58.550 rpnl:37.300
# 2015-03-30 TICK ACC.NS open: 1554.0 close: 1582.6500244140625
# 2015-03-30 POSITION value:1608.000 upnl:25.350 rpnl:37.300
# 2015-03-31 TICK ACC.NS open: 1590.199951171875 close: 1562.75
# 2015-03-31 POSITION value:1608.000 upnl:45.250 rpnl:37.300
# 2015-04-01 TICK ACC.NS open: 1563.699951171875 close: 1585.9000244140625
# 2015-04-01 POSITION value:1608.000 upnl:22.100 rpnl:37.300
# 2015-04-06 TICK ACC.NS open: 1588.0 close: 1617.4000244140625
# 2015-04-06 POSITION value:1608.000 upnl:-9.400 rpnl:37.300
# 2015-04-07 TICK ACC.NS open: 1621.4000244140625 close: 1650.300048828125
# 2015-04-07 POSITION value:1608.000 upnl:-42.300 rpnl:37.300
# 2015-04-08 TICK ACC.NS open: 1656.300048828125 close: 1636.199951171875
# 2015-04-08 POSITION value:1608.000 upnl:-28.200 rpnl:37.300
# 2015-04-09 TICK ACC.NS open: 1649.0 close: 1622.449951171875
# 2015-04-09 POSITION value:1608.000 upnl:-14.450 rpnl:37.300
# 2015-04-10 TICK ACC.NS open: 1624.0 close: 1636.050048828125
# 2015-04-10 POSITION value:1608.000 upnl:-28.050 rpnl:37.300
# 2015-04-13 TICK ACC.NS open: 1635.0 close: 1596.199951171875
# 2015-04-13 BUY signal
# 2015-04-13 ORDER BUY ACC.NS 1
# 2015-04-13 POSITION value:1608.000 upnl:11.800 rpnl:37.300
# 2015-04-15 TICK ACC.NS open: 1614.0 close: 1614.550048828125
# 2015-04-15 FILLED BUY 1 ACC.NS at 1614.0
# 2015-04-15 POSITION value:0.000 upnl:0.000 rpnl:-6.000
# 2015-04-16 TICK ACC.NS open: 1614.4000244140625 close: 1564.199951171875
# 2015-04-16 BUY signal
# 2015-04-16 ORDER BUY ACC.NS 1
# 2015-04-16 POSITION value:0.000 upnl:0.000 rpnl:-6.000
# 2015-04-17 TICK ACC.NS open: 1563.949951171875 close: 1521.6500244140625
# 2015-04-17 FILLED BUY 1 ACC.NS at 1563.949951171875
# 2015-04-17 POSITION value:-1563.950 upnl:-42.300 rpnl:-6.000
# 2015-04-20 TICK ACC.NS open: 1521.800048828125 close: 1529.75
# 2015-04-20 POSITION value:-1563.950 upnl:-34.200 rpnl:-6.000
# 2015-04-21 TICK ACC.NS open: 1532.0 close: 1496.1500244140625
# 2015-04-21 POSITION value:-1563.950 upnl:-67.800 rpnl:-6.000
# 2015-04-22 TICK ACC.NS open: 1496.25 close: 1557.300048828125
# 2015-04-22 SELL signal
# 2015-04-22 ORDER SELL ACC.NS 1
# 2015-04-22 POSITION value:-1563.950 upnl:-6.650 rpnl:-6.000
# 2015-04-23 TICK ACC.NS open: 1560.0 close: 1518.5999755859375
# 2015-04-23 FILLED SELL 1 ACC.NS at 1560.0
# 2015-04-23 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-04-24 TICK ACC.NS open: 1519.800048828125 close: 1531.5999755859375
# 2015-04-24 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-04-27 TICK ACC.NS open: 1539.949951171875 close: 1493.949951171875
# 2015-04-27 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-04-28 TICK ACC.NS open: 1488.9000244140625 close: 1514.5
# 2015-04-28 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-04-29 TICK ACC.NS open: 1514.5 close: 1484.449951171875
# 2015-04-29 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-04-30 TICK ACC.NS open: 1480.0999755859375 close: 1433.699951171875
# 2015-04-30 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-05-04 TICK ACC.NS open: 1441.0 close: 1474.5999755859375
# 2015-05-04 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-05-05 TICK ACC.NS open: 1475.0 close: 1471.4000244140625
# 2015-05-05 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-05-06 TICK ACC.NS open: 1466.0 close: 1413.300048828125
# 2015-05-06 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-05-07 TICK ACC.NS open: 1414.199951171875 close: 1451.949951171875
# 2015-05-07 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-05-08 TICK ACC.NS open: 1455.25 close: 1448.5
# 2015-05-08 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-05-11 TICK ACC.NS open: 1455.0999755859375 close: 1498.949951171875
# 2015-05-11 SELL signal
# 2015-05-11 ORDER SELL ACC.NS 1
# 2015-05-11 POSITION value:0.000 upnl:0.000 rpnl:-3.950
# 2015-05-12 TICK ACC.NS open: 1497.0999755859375 close: 1449.949951171875
# 2015-05-12 FILLED SELL 1 ACC.NS at 1497.0999755859375
# 2015-05-12 POSITION value:1497.100 upnl:47.150 rpnl:-3.950
# 2015-05-13 TICK ACC.NS open: 1459.0 close: 1472.75
# 2015-05-13 POSITION value:1497.100 upnl:24.350 rpnl:-3.950
# 2015-05-14 TICK ACC.NS open: 1471.9000244140625 close: 1474.8499755859375
# 2015-05-14 POSITION value:1497.100 upnl:22.250 rpnl:-3.950
# 2015-05-15 TICK ACC.NS open: 1478.949951171875 close: 1472.1500244140625
# 2015-05-15 POSITION value:1497.100 upnl:24.950 rpnl:-3.950
# 2015-05-18 TICK ACC.NS open: 1477.5999755859375 close: 1509.8499755859375
# 2015-05-18 POSITION value:1497.100 upnl:-12.750 rpnl:-3.950
# 2015-05-19 TICK ACC.NS open: 1510.0 close: 1497.75
# 2015-05-19 POSITION value:1497.100 upnl:-0.650 rpnl:-3.950
# 2015-05-20 TICK ACC.NS open: 1502.9000244140625 close: 1502.9000244140625
# 2015-05-20 POSITION value:1497.100 upnl:-5.800 rpnl:-3.950
# 2015-05-21 TICK ACC.NS open: 1507.699951171875 close: 1527.550048828125
# 2015-05-21 POSITION value:1497.100 upnl:-30.450 rpnl:-3.950
# 2015-05-22 TICK ACC.NS open: 1527.550048828125 close: 1519.199951171875
# 2015-05-22 POSITION value:1497.100 upnl:-22.100 rpnl:-3.950
# 2015-05-25 TICK ACC.NS open: 1520.0 close: 1495.449951171875
# 2015-05-25 POSITION value:1497.100 upnl:1.650 rpnl:-3.950
# 2015-05-26 TICK ACC.NS open: 1498.9000244140625 close: 1482.0999755859375
# 2015-05-26 POSITION value:1497.100 upnl:15.000 rpnl:-3.950
# 2015-05-27 TICK ACC.NS open: 1480.0 close: 1463.949951171875
# 2015-05-27 POSITION value:1497.100 upnl:33.150 rpnl:-3.950
# 2015-05-28 TICK ACC.NS open: 1467.9000244140625 close: 1470.699951171875
# 2015-05-28 POSITION value:1497.100 upnl:26.400 rpnl:-3.950
# 2015-05-29 TICK ACC.NS open: 1474.5999755859375 close: 1512.4000244140625
# 2015-05-29 POSITION value:1497.100 upnl:-15.300 rpnl:-3.950
# 2015-06-01 TICK ACC.NS open: 1515.0 close: 1516.3499755859375
# 2015-06-01 POSITION value:1497.100 upnl:-19.250 rpnl:-3.950
# 2015-06-02 TICK ACC.NS open: 1515.0 close: 1481.199951171875
# 2015-06-02 POSITION value:1497.100 upnl:15.900 rpnl:-3.950
# 2015-06-03 TICK ACC.NS open: 1480.0 close: 1460.0
# 2015-06-03 POSITION value:1497.100 upnl:37.100 rpnl:-3.950
# 2015-06-04 TICK ACC.NS open: 1461.5999755859375 close: 1466.9000244140625
# 2015-06-04 POSITION value:1497.100 upnl:30.200 rpnl:-3.950
# 2015-06-05 TICK ACC.NS open: 1458.0 close: 1434.5
# 2015-06-05 POSITION value:1497.100 upnl:62.600 rpnl:-3.950
# 2015-06-08 TICK ACC.NS open: 1434.5 close: 1429.550048828125
# 2015-06-08 POSITION value:1497.100 upnl:67.550 rpnl:-3.950
# 2015-06-09 TICK ACC.NS open: 1421.0 close: 1441.0999755859375
# 2015-06-09 POSITION value:1497.100 upnl:56.000 rpnl:-3.950
# 2015-06-10 TICK ACC.NS open: 1436.5 close: 1436.4000244140625
# 2015-06-10 POSITION value:1497.100 upnl:60.700 rpnl:-3.950
# 2015-06-11 TICK ACC.NS open: 1441.25 close: 1407.699951171875
# 2015-06-11 POSITION value:1497.100 upnl:89.400 rpnl:-3.950
# 2015-06-12 TICK ACC.NS open: 1407.0 close: 1402.1500244140625
# 2015-06-12 POSITION value:1497.100 upnl:94.950 rpnl:-3.950
# 2015-06-15 TICK ACC.NS open: 1404.0 close: 1370.25
# 2015-06-15 POSITION value:1497.100 upnl:126.850 rpnl:-3.950
# 2015-06-16 TICK ACC.NS open: 1366.25 close: 1387.5
# 2015-06-16 POSITION value:1497.100 upnl:109.600 rpnl:-3.950
# 2015-06-17 TICK ACC.NS open: 1392.3499755859375 close: 1410.5999755859375
# 2015-06-17 POSITION value:1497.100 upnl:86.500 rpnl:-3.950
# 2015-06-18 TICK ACC.NS open: 1413.300048828125 close: 1413.75
# 2015-06-18 POSITION value:1497.100 upnl:83.350 rpnl:-3.950
# 2015-06-19 TICK ACC.NS open: 1417.550048828125 close: 1425.1500244140625
# 2015-06-19 POSITION value:1497.100 upnl:71.950 rpnl:-3.950
# 2015-06-22 TICK ACC.NS open: 1425.0999755859375 close: 1427.449951171875
# 2015-06-22 POSITION value:1497.100 upnl:69.650 rpnl:-3.950
# 2015-06-23 TICK ACC.NS open: 1427.449951171875 close: 1447.1500244140625
# 2015-06-23 POSITION value:1497.100 upnl:49.950 rpnl:-3.950
# 2015-06-24 TICK ACC.NS open: 1452.5 close: 1410.6500244140625
# 2015-06-24 POSITION value:1497.100 upnl:86.450 rpnl:-3.950
# 2015-06-25 TICK ACC.NS open: 1410.0 close: 1407.75
# 2015-06-25 POSITION value:1497.100 upnl:89.350 rpnl:-3.950
# 2015-06-26 TICK ACC.NS open: 1407.9000244140625 close: 1420.8499755859375
# 2015-06-26 POSITION value:1497.100 upnl:76.250 rpnl:-3.950
# 2015-06-29 TICK ACC.NS open: 1408.0 close: 1411.75
# 2015-06-29 POSITION value:1497.100 upnl:85.350 rpnl:-3.950
# 2015-06-30 TICK ACC.NS open: 1404.0 close: 1444.550048828125
# 2015-06-30 POSITION value:1497.100 upnl:52.550 rpnl:-3.950
# 2015-07-01 TICK ACC.NS open: 1440.0999755859375 close: 1465.75
# 2015-07-01 POSITION value:1497.100 upnl:31.350 rpnl:-3.950
# 2015-07-02 TICK ACC.NS open: 1467.550048828125 close: 1471.550048828125
# 2015-07-02 POSITION value:1497.100 upnl:25.550 rpnl:-3.950
# 2015-07-03 TICK ACC.NS open: 1466.0 close: 1480.4000244140625
# 2015-07-03 POSITION value:1497.100 upnl:16.700 rpnl:-3.950
# 2015-07-06 TICK ACC.NS open: 1468.699951171875 close: 1504.949951171875
# 2015-07-06 POSITION value:1497.100 upnl:-7.850 rpnl:-3.950
# 2015-07-07 TICK ACC.NS open: 1500.0999755859375 close: 1500.0999755859375
# 2015-07-07 POSITION value:1497.100 upnl:-3.000 rpnl:-3.950
# 2015-07-08 TICK ACC.NS open: 1493.0 close: 1467.699951171875
# 2015-07-08 BUY signal
# 2015-07-08 ORDER BUY ACC.NS 1
# 2015-07-08 POSITION value:1497.100 upnl:29.400 rpnl:-3.950
# 2015-07-09 TICK ACC.NS open: 1475.0 close: 1485.050048828125
# 2015-07-09 FILLED BUY 1 ACC.NS at 1475.0
# 2015-07-09 POSITION value:0.000 upnl:0.000 rpnl:22.100
# 2015-07-10 TICK ACC.NS open: 1490.25 close: 1472.199951171875
# 2015-07-10 POSITION value:0.000 upnl:0.000 rpnl:22.100
# 2015-07-13 TICK ACC.NS open: 1467.25 close: 1475.050048828125
# 2015-07-13 POSITION value:0.000 upnl:0.000 rpnl:22.100
# 2015-07-14 TICK ACC.NS open: 1476.800048828125 close: 1478.449951171875
# 2015-07-14 POSITION value:0.000 upnl:0.000 rpnl:22.100
# 2015-07-15 TICK ACC.NS open: 1483.800048828125 close: 1496.949951171875
# 2015-07-15 POSITION value:0.000 upnl:0.000 rpnl:22.100
# 2015-07-16 TICK ACC.NS open: 1500.0 close: 1496.9000244140625
# 2015-07-16 POSITION value:0.000 upnl:0.000 rpnl:22.100
# 2015-07-17 TICK ACC.NS open: 1490.0 close: 1486.0
# 2015-07-17 POSITION value:0.000 upnl:0.000 rpnl:22.100
# 2015-07-20 TICK ACC.NS open: 1436.0999755859375 close: 1455.0999755859375
# 2015-07-20 BUY signal
# 2015-07-20 ORDER BUY ACC.NS 1
# 2015-07-20 POSITION value:0.000 upnl:0.000 rpnl:22.100
# 2015-07-21 TICK ACC.NS open: 1455.0999755859375 close: 1439.5999755859375
# 2015-07-21 FILLED BUY 1 ACC.NS at 1455.0999755859375
# 2015-07-21 POSITION value:-1455.100 upnl:-15.500 rpnl:22.100
# 2015-07-22 TICK ACC.NS open: 1432.5 close: 1437.199951171875
# 2015-07-22 POSITION value:-1455.100 upnl:-17.900 rpnl:22.100
# 2015-07-23 TICK ACC.NS open: 1442.0 close: 1424.4000244140625
# 2015-07-23 POSITION value:-1455.100 upnl:-30.700 rpnl:22.100
# 2015-07-24 TICK ACC.NS open: 1428.0 close: 1408.800048828125
# 2015-07-24 POSITION value:-1455.100 upnl:-46.300 rpnl:22.100
# 2015-07-27 TICK ACC.NS open: 1404.0 close: 1369.25
# 2015-07-27 POSITION value:-1455.100 upnl:-85.850 rpnl:22.100
# 2015-07-28 TICK ACC.NS open: 1371.699951171875 close: 1359.1500244140625
# 2015-07-28 POSITION value:-1455.100 upnl:-95.950 rpnl:22.100
# 2015-07-29 TICK ACC.NS open: 1368.449951171875 close: 1369.949951171875
# 2015-07-29 POSITION value:-1455.100 upnl:-85.150 rpnl:22.100
# 2015-07-30 TICK ACC.NS open: 1379.699951171875 close: 1371.1500244140625
# 2015-07-30 POSITION value:-1455.100 upnl:-83.950 rpnl:22.100
# 2015-07-31 TICK ACC.NS open: 1375.0 close: 1387.4000244140625
# 2015-07-31 POSITION value:-1455.100 upnl:-67.700 rpnl:22.100
# 2015-08-03 TICK ACC.NS open: 1384.800048828125 close: 1391.5999755859375
# 2015-08-03 POSITION value:-1455.100 upnl:-63.500 rpnl:22.100
# 2015-08-04 TICK ACC.NS open: 1403.699951171875 close: 1377.199951171875
# 2015-08-04 POSITION value:-1455.100 upnl:-77.900 rpnl:22.100
# 2015-08-05 TICK ACC.NS open: 1380.0 close: 1381.75
# 2015-08-05 POSITION value:-1455.100 upnl:-73.350 rpnl:22.100
# 2015-08-06 TICK ACC.NS open: 1382.0 close: 1405.3499755859375
# 2015-08-06 SELL signal
# 2015-08-06 ORDER SELL ACC.NS 1
# 2015-08-06 POSITION value:-1455.100 upnl:-49.750 rpnl:22.100
# 2015-08-07 TICK ACC.NS open: 1407.9000244140625 close: 1399.6500244140625
# 2015-08-07 FILLED SELL 1 ACC.NS at 1407.9000244140625
# 2015-08-07 POSITION value:0.000 upnl:0.000 rpnl:-47.200
# 2015-08-10 TICK ACC.NS open: 1398.0 close: 1385.75
# 2015-08-10 POSITION value:0.000 upnl:0.000 rpnl:-47.200
# 2015-08-11 TICK ACC.NS open: 1384.9000244140625 close: 1374.25
# 2015-08-11 POSITION value:0.000 upnl:0.000 rpnl:-47.200
# 2015-08-12 TICK ACC.NS open: 1370.0 close: 1366.0
# 2015-08-12 POSITION value:0.000 upnl:0.000 rpnl:-47.200
# 2015-08-13 TICK ACC.NS open: 1370.0 close: 1364.550048828125
# 2015-08-13 POSITION value:0.000 upnl:0.000 rpnl:-47.200
# 2015-08-14 TICK ACC.NS open: 1367.0 close: 1372.050048828125
# 2015-08-14 POSITION value:0.000 upnl:0.000 rpnl:-47.200
# 2015-08-17 TICK ACC.NS open: 1378.0 close: 1367.3499755859375
# 2015-08-17 POSITION value:0.000 upnl:0.000 rpnl:-47.200
# 2015-08-18 TICK ACC.NS open: 1370.199951171875 close: 1387.3499755859375
# 2015-08-18 SELL signal
# 2015-08-18 ORDER SELL ACC.NS 1
# 2015-08-18 POSITION value:0.000 upnl:0.000 rpnl:-47.200
# 2015-08-19 TICK ACC.NS open: 1393.0 close: 1446.9000244140625
# 2015-08-19 FILLED SELL 1 ACC.NS at 1393.0
# 2015-08-19 POSITION value:1393.000 upnl:-53.900 rpnl:-47.200
# 2015-08-20 TICK ACC.NS open: 1440.0999755859375 close: 1411.0
# 2015-08-20 BUY signal
# 2015-08-20 ORDER BUY ACC.NS 1
# 2015-08-20 POSITION value:1393.000 upnl:-18.000 rpnl:-47.200
# 2015-08-21 TICK ACC.NS open: 1405.0 close: 1406.449951171875
# 2015-08-21 FILLED BUY 1 ACC.NS at 1405.0
# 2015-08-21 POSITION value:0.000 upnl:0.000 rpnl:-12.000
# 2015-08-24 TICK ACC.NS open: 1375.0 close: 1367.1500244140625
# 2015-08-24 BUY signal
# 2015-08-24 ORDER BUY ACC.NS 1
# 2015-08-24 POSITION value:0.000 upnl:0.000 rpnl:-12.000
# 2015-08-25 TICK ACC.NS open: 1376.0 close: 1362.0999755859375
# 2015-08-25 FILLED BUY 1 ACC.NS at 1376.0
# 2015-08-25 POSITION value:-1376.000 upnl:-13.900 rpnl:-12.000
# 2015-08-26 TICK ACC.NS open: 1362.1500244140625 close: 1360.4000244140625
# 2015-08-26 POSITION value:-1376.000 upnl:-15.600 rpnl:-12.000
# 2015-08-27 TICK ACC.NS open: 1370.4000244140625 close: 1369.949951171875
# 2015-08-27 POSITION value:-1376.000 upnl:-6.050 rpnl:-12.000
# 2015-08-28 TICK ACC.NS open: 1387.9000244140625 close: 1362.800048828125
# 2015-08-28 POSITION value:-1376.000 upnl:-13.200 rpnl:-12.000
# 2015-08-31 TICK ACC.NS open: 1362.800048828125 close: 1334.8499755859375
# 2015-08-31 POSITION value:-1376.000 upnl:-41.150 rpnl:-12.000
# 2015-09-01 TICK ACC.NS open: 1321.0 close: 1332.199951171875
# 2015-09-01 POSITION value:-1376.000 upnl:-43.800 rpnl:-12.000
# 2015-09-02 TICK ACC.NS open: 1349.800048828125 close: 1356.3499755859375
# 2015-09-02 POSITION value:-1376.000 upnl:-19.650 rpnl:-12.000
# 2015-09-03 TICK ACC.NS open: 1361.0999755859375 close: 1394.550048828125
# 2015-09-03 SELL signal
# 2015-09-03 ORDER SELL ACC.NS 1
# 2015-09-03 POSITION value:-1376.000 upnl:18.550 rpnl:-12.000
# 2015-09-04 TICK ACC.NS open: 1394.550048828125 close: 1345.4000244140625
# 2015-09-04 FILLED SELL 1 ACC.NS at 1394.550048828125
# 2015-09-04 BUY signal
# 2015-09-04 ORDER BUY ACC.NS 1
# 2015-09-04 POSITION value:0.000 upnl:0.000 rpnl:18.550
# 2015-09-07 TICK ACC.NS open: 1359.9000244140625 close: 1344.949951171875
# 2015-09-07 FILLED BUY 1 ACC.NS at 1359.9000244140625
# 2015-09-07 POSITION value:-1359.900 upnl:-14.950 rpnl:18.550
# 2015-09-08 TICK ACC.NS open: 1348.0 close: 1345.800048828125
# 2015-09-08 POSITION value:-1359.900 upnl:-14.100 rpnl:18.550
# 2015-09-09 TICK ACC.NS open: 1360.0 close: 1380.050048828125
# 2015-09-09 POSITION value:-1359.900 upnl:20.150 rpnl:18.550
# 2015-09-10 TICK ACC.NS open: 1367.25 close: 1378.9000244140625
# 2015-09-10 POSITION value:-1359.900 upnl:19.000 rpnl:18.550
# 2015-09-11 TICK ACC.NS open: 1381.0 close: 1366.550048828125
# 2015-09-11 POSITION value:-1359.900 upnl:6.650 rpnl:18.550
# 2015-09-14 TICK ACC.NS open: 1367.5 close: 1388.6500244140625
# 2015-09-14 POSITION value:-1359.900 upnl:28.750 rpnl:18.550
# 2015-09-15 TICK ACC.NS open: 1385.0 close: 1379.5
# 2015-09-15 POSITION value:-1359.900 upnl:19.600 rpnl:18.550
# 2015-09-16 TICK ACC.NS open: 1385.0 close: 1377.300048828125
# 2015-09-16 POSITION value:-1359.900 upnl:17.400 rpnl:18.550
# 2015-09-18 TICK ACC.NS open: 1386.0 close: 1375.199951171875
# 2015-09-18 POSITION value:-1359.900 upnl:15.300 rpnl:18.550
# 2015-09-21 TICK ACC.NS open: 1364.449951171875 close: 1383.4000244140625
# 2015-09-21 POSITION value:-1359.900 upnl:23.500 rpnl:18.550
# 2015-09-22 TICK ACC.NS open: 1389.0 close: 1353.550048828125
# 2015-09-22 POSITION value:-1359.900 upnl:-6.350 rpnl:18.550
# 2015-09-23 TICK ACC.NS open: 1335.0 close: 1345.6500244140625
# 2015-09-23 POSITION value:-1359.900 upnl:-14.250 rpnl:18.550
# 2015-09-24 TICK ACC.NS open: 1343.0999755859375 close: 1343.050048828125
# 2015-09-24 POSITION value:-1359.900 upnl:-16.850 rpnl:18.550
# 2015-09-28 TICK ACC.NS open: 1343.5 close: 1336.75
# 2015-09-28 POSITION value:-1359.900 upnl:-23.150 rpnl:18.550
# 2015-09-29 TICK ACC.NS open: 1325.0 close: 1327.449951171875
# 2015-09-29 POSITION value:-1359.900 upnl:-32.450 rpnl:18.550
# 2015-09-30 TICK ACC.NS open: 1340.0 close: 1346.75
# 2015-09-30 POSITION value:-1359.900 upnl:-13.150 rpnl:18.550
# 2015-10-01 TICK ACC.NS open: 1354.5 close: 1363.0999755859375
# 2015-10-01 POSITION value:-1359.900 upnl:3.200 rpnl:18.550
# 2015-10-05 TICK ACC.NS open: 1372.199951171875 close: 1369.699951171875
# 2015-10-05 POSITION value:-1359.900 upnl:9.800 rpnl:18.550
# 2015-10-06 TICK ACC.NS open: 1377.0 close: 1350.4000244140625
# 2015-10-06 POSITION value:-1359.900 upnl:-9.500 rpnl:18.550
# 2015-10-07 TICK ACC.NS open: 1353.5 close: 1352.25
# 2015-10-07 POSITION value:-1359.900 upnl:-7.650 rpnl:18.550
# 2015-10-08 TICK ACC.NS open: 1354.0 close: 1356.199951171875
# 2015-10-08 POSITION value:-1359.900 upnl:-3.700 rpnl:18.550
# 2015-10-09 TICK ACC.NS open: 1363.199951171875 close: 1347.3499755859375
# 2015-10-09 POSITION value:-1359.900 upnl:-12.550 rpnl:18.550
# 2015-10-12 TICK ACC.NS open: 1350.0 close: 1344.3499755859375
# 2015-10-12 POSITION value:-1359.900 upnl:-15.550 rpnl:18.550
# 2015-10-13 TICK ACC.NS open: 1344.3499755859375 close: 1352.199951171875
# 2015-10-13 POSITION value:-1359.900 upnl:-7.700 rpnl:18.550
# 2015-10-14 TICK ACC.NS open: 1352.0 close: 1376.25
# 2015-10-14 SELL signal
# 2015-10-14 ORDER SELL ACC.NS 1
# 2015-10-14 POSITION value:-1359.900 upnl:16.350 rpnl:18.550
# 2015-10-15 TICK ACC.NS open: 1383.800048828125 close: 1371.25
# 2015-10-15 FILLED SELL 1 ACC.NS at 1383.800048828125
# 2015-10-15 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-16 TICK ACC.NS open: 1375.0 close: 1393.0
# 2015-10-16 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-19 TICK ACC.NS open: 1398.5 close: 1395.949951171875
# 2015-10-19 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-20 TICK ACC.NS open: 1382.3499755859375 close: 1379.300048828125
# 2015-10-20 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-21 TICK ACC.NS open: 1360.0 close: 1378.949951171875
# 2015-10-21 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-23 TICK ACC.NS open: 1394.0 close: 1400.199951171875
# 2015-10-23 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-26 TICK ACC.NS open: 1405.0 close: 1393.75
# 2015-10-26 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-27 TICK ACC.NS open: 1390.0 close: 1385.800048828125
# 2015-10-27 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-28 TICK ACC.NS open: 1385.9000244140625 close: 1401.050048828125
# 2015-10-28 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-29 TICK ACC.NS open: 1395.0 close: 1385.4000244140625
# 2015-10-29 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-10-30 TICK ACC.NS open: 1398.699951171875 close: 1379.5999755859375
# 2015-10-30 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-11-02 TICK ACC.NS open: 1373.25 close: 1398.4000244140625
# 2015-11-02 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-11-03 TICK ACC.NS open: 1405.0 close: 1425.9000244140625
# 2015-11-03 SELL signal
# 2015-11-03 ORDER SELL ACC.NS 1
# 2015-11-03 POSITION value:0.000 upnl:0.000 rpnl:23.900
# 2015-11-04 TICK ACC.NS open: 1440.0 close: 1405.699951171875
# 2015-11-04 FILLED SELL 1 ACC.NS at 1440.0
# 2015-11-04 BUY signal
# 2015-11-04 ORDER BUY ACC.NS 1
# 2015-11-04 POSITION value:1440.000 upnl:34.300 rpnl:23.900
# 2015-11-05 TICK ACC.NS open: 1410.0 close: 1388.75
# 2015-11-05 FILLED BUY 1 ACC.NS at 1410.0
# 2015-11-05 POSITION value:0.000 upnl:0.000 rpnl:30.000
# 2015-11-06 TICK ACC.NS open: 1388.0 close: 1384.050048828125
# 2015-11-06 POSITION value:0.000 upnl:0.000 rpnl:30.000
# 2015-11-09 TICK ACC.NS open: 1359.1500244140625 close: 1367.699951171875
# 2015-11-09 POSITION value:0.000 upnl:0.000 rpnl:30.000
# 2015-11-10 TICK ACC.NS open: 1359.0 close: 1322.0999755859375
# 2015-11-10 BUY signal
# 2015-11-10 ORDER BUY ACC.NS 1
# 2015-11-10 POSITION value:0.000 upnl:0.000 rpnl:30.000
# 2015-11-13 TICK ACC.NS open: 1321.5 close: 1326.699951171875
# 2015-11-13 FILLED BUY 1 ACC.NS at 1321.5
# 2015-11-13 POSITION value:-1321.500 upnl:5.200 rpnl:30.000
# 2015-11-16 TICK ACC.NS open: 1324.9000244140625 close: 1324.449951171875
# 2015-11-16 POSITION value:-1321.500 upnl:2.950 rpnl:30.000
# 2015-11-17 TICK ACC.NS open: 1330.0 close: 1325.5
# 2015-11-17 POSITION value:-1321.500 upnl:4.000 rpnl:30.000
# 2015-11-18 TICK ACC.NS open: 1324.0 close: 1334.300048828125
# 2015-11-18 POSITION value:-1321.500 upnl:12.800 rpnl:30.000
# 2015-11-19 TICK ACC.NS open: 1336.0 close: 1332.8499755859375
# 2015-11-19 POSITION value:-1321.500 upnl:11.350 rpnl:30.000
# 2015-11-20 TICK ACC.NS open: 1333.0 close: 1339.75
# 2015-11-20 POSITION value:-1321.500 upnl:18.250 rpnl:30.000
# 2015-11-23 TICK ACC.NS open: 1340.0 close: 1343.5999755859375
# 2015-11-23 POSITION value:-1321.500 upnl:22.100 rpnl:30.000
# 2015-11-24 TICK ACC.NS open: 1343.800048828125 close: 1341.5
# 2015-11-24 POSITION value:-1321.500 upnl:20.000 rpnl:30.000
# 2015-11-26 TICK ACC.NS open: 1347.9000244140625 close: 1355.949951171875
# 2015-11-26 POSITION value:-1321.500 upnl:34.450 rpnl:30.000
# 2015-11-27 TICK ACC.NS open: 1357.300048828125 close: 1353.199951171875
# 2015-11-27 POSITION value:-1321.500 upnl:31.700 rpnl:30.000
# 2015-11-30 TICK ACC.NS open: 1356.9000244140625 close: 1345.0
# 2015-11-30 POSITION value:-1321.500 upnl:23.500 rpnl:30.000
# 2015-12-01 TICK ACC.NS open: 1349.0 close: 1357.9000244140625
# 2015-12-01 POSITION value:-1321.500 upnl:36.400 rpnl:30.000
# 2015-12-02 TICK ACC.NS open: 1362.5 close: 1359.8499755859375
# 2015-12-02 POSITION value:-1321.500 upnl:38.350 rpnl:30.000
# 2015-12-03 TICK ACC.NS open: 1356.0 close: 1350.0999755859375
# 2015-12-03 POSITION value:-1321.500 upnl:28.600 rpnl:30.000
# 2015-12-04 TICK ACC.NS open: 1340.0 close: 1334.8499755859375
# 2015-12-04 POSITION value:-1321.500 upnl:13.350 rpnl:30.000
# 2015-12-07 TICK ACC.NS open: 1336.449951171875 close: 1353.449951171875
# 2015-12-07 POSITION value:-1321.500 upnl:31.950 rpnl:30.000
# 2015-12-08 TICK ACC.NS open: 1348.699951171875 close: 1339.199951171875
# 2015-12-08 POSITION value:-1321.500 upnl:17.700 rpnl:30.000
# 2015-12-09 TICK ACC.NS open: 1340.0 close: 1313.75
# 2015-12-09 POSITION value:-1321.500 upnl:-7.750 rpnl:30.000
# 2015-12-10 TICK ACC.NS open: 1316.0 close: 1324.449951171875
# 2015-12-10 POSITION value:-1321.500 upnl:2.950 rpnl:30.000
# 2015-12-11 TICK ACC.NS open: 1325.5 close: 1319.4000244140625
# 2015-12-11 POSITION value:-1321.500 upnl:-2.100 rpnl:30.000
# 2015-12-14 TICK ACC.NS open: 1315.0 close: 1341.800048828125
# 2015-12-14 SELL signal
# 2015-12-14 ORDER SELL ACC.NS 1
# 2015-12-14 POSITION value:-1321.500 upnl:20.300 rpnl:30.000
# 2015-12-15 TICK ACC.NS open: 1343.25 close: 1337.6500244140625
# 2015-12-15 FILLED SELL 1 ACC.NS at 1343.25
# 2015-12-15 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-16 TICK ACC.NS open: 1349.5 close: 1349.0999755859375
# 2015-12-16 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-17 TICK ACC.NS open: 1351.9000244140625 close: 1356.199951171875
# 2015-12-17 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-18 TICK ACC.NS open: 1354.9000244140625 close: 1349.0
# 2015-12-18 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-21 TICK ACC.NS open: 1346.0999755859375 close: 1353.0
# 2015-12-21 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-22 TICK ACC.NS open: 1349.5 close: 1348.9000244140625
# 2015-12-22 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-23 TICK ACC.NS open: 1356.699951171875 close: 1342.050048828125
# 2015-12-23 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-24 TICK ACC.NS open: 1347.75 close: 1344.1500244140625
# 2015-12-24 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-28 TICK ACC.NS open: 1345.0 close: 1330.8499755859375
# 2015-12-28 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-29 TICK ACC.NS open: 1334.800048828125 close: 1350.449951171875
# 2015-12-29 SELL signal
# 2015-12-29 ORDER SELL ACC.NS 1
# 2015-12-29 POSITION value:0.000 upnl:0.000 rpnl:21.750
# 2015-12-30 TICK ACC.NS open: 1349.0 close: 1349.800048828125
# 2015-12-30 FILLED SELL 1 ACC.NS at 1349.0
# 2015-12-30 POSITION value:1349.000 upnl:-0.800 rpnl:21.750
# 2015-12-31 TICK ACC.NS open: 1345.0 close: 1360.6500244140625
# 2015-12-31 POSITION value:1349.000 upnl:-11.650 rpnl:21.750
# 2016-01-01 TICK ACC.NS open: 1362.0 close: 1373.6500244140625
# 2016-01-01 POSITION value:1349.000 upnl:-24.650 rpnl:21.750
# 2016-01-04 TICK ACC.NS open: 1368.4000244140625 close: 1344.0
# 2016-01-04 BUY signal
# 2016-01-04 ORDER BUY ACC.NS 1
# 2016-01-04 POSITION value:1349.000 upnl:5.000 rpnl:21.750
# 2016-01-05 TICK ACC.NS open: 1345.0 close: 1341.300048828125
# 2016-01-05 FILLED BUY 1 ACC.NS at 1345.0
# 2016-01-05 POSITION value:0.000 upnl:0.000 rpnl:4.000
# 2016-01-06 TICK ACC.NS open: 1348.0 close: 1320.3499755859375
# 2016-01-06 BUY signal
# 2016-01-06 ORDER BUY ACC.NS 1
# 2016-01-06 POSITION value:0.000 upnl:0.000 rpnl:4.000
# 2016-01-07 TICK ACC.NS open: 1317.75 close: 1300.5
# 2016-01-07 FILLED BUY 1 ACC.NS at 1317.75
# 2016-01-07 POSITION value:-1317.750 upnl:-17.250 rpnl:4.000
# 2016-01-08 TICK ACC.NS open: 1302.9000244140625 close: 1295.800048828125
# 2016-01-08 POSITION value:-1317.750 upnl:-21.950 rpnl:4.000
# 2016-01-11 TICK ACC.NS open: 1287.800048828125 close: 1297.550048828125
# 2016-01-11 POSITION value:-1317.750 upnl:-20.200 rpnl:4.000
# 2016-01-12 TICK ACC.NS open: 1295.25 close: 1280.4000244140625
# 2016-01-12 POSITION value:-1317.750 upnl:-37.350 rpnl:4.000
# 2016-01-13 TICK ACC.NS open: 1290.0 close: 1281.949951171875
# 2016-01-13 POSITION value:-1317.750 upnl:-35.800 rpnl:4.000
# 2016-01-14 TICK ACC.NS open: 1270.0 close: 1269.050048828125
# 2016-01-14 POSITION value:-1317.750 upnl:-48.700 rpnl:4.000
# 2016-01-15 TICK ACC.NS open: 1275.0 close: 1229.5999755859375
# 2016-01-15 POSITION value:-1317.750 upnl:-88.150 rpnl:4.000
# 2016-01-18 TICK ACC.NS open: 1232.5 close: 1224.25
# 2016-01-18 POSITION value:-1317.750 upnl:-93.500 rpnl:4.000
# 2016-01-19 TICK ACC.NS open: 1230.0 close: 1235.300048828125
# 2016-01-19 POSITION value:-1317.750 upnl:-82.450 rpnl:4.000
# 2016-01-20 TICK ACC.NS open: 1218.9000244140625 close: 1212.25
# 2016-01-20 POSITION value:-1317.750 upnl:-105.500 rpnl:4.000
# 2016-01-21 TICK ACC.NS open: 1225.0 close: 1228.449951171875
# 2016-01-21 POSITION value:-1317.750 upnl:-89.300 rpnl:4.000
# 2016-01-22 TICK ACC.NS open: 1239.949951171875 close: 1241.0
# 2016-01-22 POSITION value:-1317.750 upnl:-76.750 rpnl:4.000
# 2016-01-25 TICK ACC.NS open: 1250.0 close: 1245.0
# 2016-01-25 POSITION value:-1317.750 upnl:-72.750 rpnl:4.000
# 2016-01-27 TICK ACC.NS open: 1249.0 close: 1230.3499755859375
# 2016-01-27 POSITION value:-1317.750 upnl:-87.400 rpnl:4.000
# 2016-01-28 TICK ACC.NS open: 1232.4000244140625 close: 1214.949951171875
# 2016-01-28 POSITION value:-1317.750 upnl:-102.800 rpnl:4.000
# 2016-01-29 TICK ACC.NS open: 1220.0999755859375 close: 1240.050048828125
# 2016-01-29 SELL signal
# 2016-01-29 ORDER SELL ACC.NS 1
# 2016-01-29 POSITION value:-1317.750 upnl:-77.700 rpnl:4.000
# 2016-02-01 TICK ACC.NS open: 1245.0 close: 1271.8499755859375
# 2016-02-01 FILLED SELL 1 ACC.NS at 1245.0
# 2016-02-01 SELL signal
# 2016-02-01 ORDER SELL ACC.NS 1
# 2016-02-01 POSITION value:0.000 upnl:0.000 rpnl:-72.750
# 2016-02-02 TICK ACC.NS open: 1266.800048828125 close: 1261.3499755859375
# 2016-02-02 FILLED SELL 1 ACC.NS at 1266.800048828125
# 2016-02-02 POSITION value:1266.800 upnl:5.450 rpnl:-72.750
# 2016-02-03 TICK ACC.NS open: 1244.0 close: 1248.949951171875
# 2016-02-03 POSITION value:1266.800 upnl:17.850 rpnl:-72.750
# 2016-02-04 TICK ACC.NS open: 1255.25 close: 1270.4000244140625
# 2016-02-04 POSITION value:1266.800 upnl:-3.600 rpnl:-72.750
# 2016-02-05 TICK ACC.NS open: 1267.050048828125 close: 1271.4000244140625
# 2016-02-05 POSITION value:1266.800 upnl:-4.600 rpnl:-72.750
# 2016-02-08 TICK ACC.NS open: 1271.0 close: 1280.5999755859375
# 2016-02-08 POSITION value:1266.800 upnl:-13.800 rpnl:-72.750
# 2016-02-09 TICK ACC.NS open: 1271.0 close: 1279.0999755859375
# 2016-02-09 POSITION value:1266.800 upnl:-12.300 rpnl:-72.750
# 2016-02-10 TICK ACC.NS open: 1270.0 close: 1265.8499755859375
# 2016-02-10 POSITION value:1266.800 upnl:0.950 rpnl:-72.750
# 2016-02-11 TICK ACC.NS open: 1250.0 close: 1234.0
# 2016-02-11 BUY signal
# 2016-02-11 ORDER BUY ACC.NS 1
# 2016-02-11 POSITION value:1266.800 upnl:32.800 rpnl:-72.750
# 2016-02-12 TICK ACC.NS open: 1234.199951171875 close: 1221.050048828125
# 2016-02-12 FILLED BUY 1 ACC.NS at 1234.199951171875
# 2016-02-12 POSITION value:0.000 upnl:0.000 rpnl:32.600
# 2016-02-15 TICK ACC.NS open: 1230.0 close: 1256.550048828125
# 2016-02-15 SELL signal
# 2016-02-15 ORDER SELL ACC.NS 1
# 2016-02-15 POSITION value:0.000 upnl:0.000 rpnl:32.600
# 2016-02-16 TICK ACC.NS open: 1265.0 close: 1227.800048828125
# 2016-02-16 FILLED SELL 1 ACC.NS at 1265.0
# 2016-02-16 POSITION value:1265.000 upnl:37.200 rpnl:32.600
# 2016-02-17 TICK ACC.NS open: 1222.800048828125 close: 1226.050048828125
# 2016-02-17 POSITION value:1265.000 upnl:38.950 rpnl:32.600
# 2016-02-18 TICK ACC.NS open: 1235.0 close: 1262.3499755859375
# 2016-02-18 POSITION value:1265.000 upnl:2.650 rpnl:32.600
# 2016-02-19 TICK ACC.NS open: 1259.800048828125 close: 1278.0
# 2016-02-19 POSITION value:1265.000 upnl:-13.000 rpnl:32.600
# 2016-02-22 TICK ACC.NS open: 1274.5 close: 1281.5
# 2016-02-22 POSITION value:1265.000 upnl:-16.500 rpnl:32.600
# 2016-02-23 TICK ACC.NS open: 1271.0999755859375 close: 1243.9000244140625
# 2016-02-23 BUY signal
# 2016-02-23 ORDER BUY ACC.NS 1
# 2016-02-23 POSITION value:1265.000 upnl:21.100 rpnl:32.600
# 2016-02-24 TICK ACC.NS open: 1239.0 close: 1233.1500244140625
# 2016-02-24 FILLED BUY 1 ACC.NS at 1239.0
# 2016-02-24 POSITION value:0.000 upnl:0.000 rpnl:26.000
# 2016-02-25 TICK ACC.NS open: 1231.4000244140625 close: 1199.8499755859375
# 2016-02-25 POSITION value:0.000 upnl:0.000 rpnl:26.000
# 2016-02-26 TICK ACC.NS open: 1210.300048828125 close: 1190.9000244140625
# 2016-02-26 POSITION value:0.000 upnl:0.000 rpnl:26.000
# 2016-02-29 TICK ACC.NS open: 1189.0 close: 1193.9000244140625
# 2016-02-29 POSITION value:0.000 upnl:0.000 rpnl:26.000
# 2016-03-01 TICK ACC.NS open: 1199.0 close: 1232.9000244140625
# 2016-03-01 SELL signal
# 2016-03-01 ORDER SELL ACC.NS 1
# 2016-03-01 POSITION value:0.000 upnl:0.000 rpnl:26.000
# 2016-03-02 TICK ACC.NS open: 1240.0 close: 1243.25
# 2016-03-02 FILLED SELL 1 ACC.NS at 1240.0
# 2016-03-02 POSITION value:1240.000 upnl:-3.250 rpnl:26.000
# 2016-03-03 TICK ACC.NS open: 1245.699951171875 close: 1254.1500244140625
# 2016-03-03 POSITION value:1240.000 upnl:-14.150 rpnl:26.000
# 2016-03-04 TICK ACC.NS open: 1255.0 close: 1239.3499755859375
# 2016-03-04 POSITION value:1240.000 upnl:0.650 rpnl:26.000
# 2016-03-08 TICK ACC.NS open: 1239.0999755859375 close: 1241.1500244140625
# 2016-03-08 POSITION value:1240.000 upnl:-1.150 rpnl:26.000
# 2016-03-09 TICK ACC.NS open: 1237.300048828125 close: 1243.75
# 2016-03-09 POSITION value:1240.000 upnl:-3.750 rpnl:26.000
# 2016-03-10 TICK ACC.NS open: 1248.0 close: 1230.3499755859375
# 2016-03-10 POSITION value:1240.000 upnl:9.650 rpnl:26.000
# 2016-03-11 TICK ACC.NS open: 1225.0 close: 1226.75
# 2016-03-11 POSITION value:1240.000 upnl:13.250 rpnl:26.000
# 2016-03-14 TICK ACC.NS open: 1231.300048828125 close: 1235.800048828125
# 2016-03-14 POSITION value:1240.000 upnl:4.200 rpnl:26.000
# 2016-03-15 TICK ACC.NS open: 1236.0 close: 1240.0999755859375
# 2016-03-15 POSITION value:1240.000 upnl:-0.100 rpnl:26.000
# 2016-03-16 TICK ACC.NS open: 1240.4000244140625 close: 1236.1500244140625
# 2016-03-16 POSITION value:1240.000 upnl:3.850 rpnl:26.000
# 2016-03-17 TICK ACC.NS open: 1243.9000244140625 close: 1273.699951171875
# 2016-03-17 POSITION value:1240.000 upnl:-33.700 rpnl:26.000
# 2016-03-18 TICK ACC.NS open: 1280.0999755859375 close: 1337.199951171875
# 2016-03-18 POSITION value:1240.000 upnl:-97.200 rpnl:26.000
# 2016-03-21 TICK ACC.NS open: 1344.3499755859375 close: 1374.3499755859375
# 2016-03-21 POSITION value:1240.000 upnl:-134.350 rpnl:26.000
# 2016-03-22 TICK ACC.NS open: 1374.0 close: 1365.5
# 2016-03-22 POSITION value:1240.000 upnl:-125.500 rpnl:26.000
# 2016-03-23 TICK ACC.NS open: 1368.0 close: 1372.6500244140625
# 2016-03-23 POSITION value:1240.000 upnl:-132.650 rpnl:26.000
# 2016-03-28 TICK ACC.NS open: 1372.6500244140625 close: 1377.550048828125
# 2016-03-28 POSITION value:1240.000 upnl:-137.550 rpnl:26.000
# 2016-03-29 TICK ACC.NS open: 1367.050048828125 close: 1366.050048828125
# 2016-03-29 POSITION value:1240.000 upnl:-126.050 rpnl:26.000
# 2016-03-30 TICK ACC.NS open: 1373.0 close: 1385.699951171875
# 2016-03-30 POSITION value:1240.000 upnl:-145.700 rpnl:26.000
# 2016-03-31 TICK ACC.NS open: 1395.0 close: 1381.9000244140625
# 2016-03-31 POSITION value:1240.000 upnl:-141.900 rpnl:26.000
# 2016-04-01 TICK ACC.NS open: 1371.25 close: 1413.800048828125
# 2016-04-01 POSITION value:1240.000 upnl:-173.800 rpnl:26.000
# 2016-04-04 TICK ACC.NS open: 1409.949951171875 close: 1412.0999755859375
# 2016-04-04 POSITION value:1240.000 upnl:-172.100 rpnl:26.000
# 2016-04-05 TICK ACC.NS open: 1405.0 close: 1390.75
# 2016-04-05 POSITION value:1240.000 upnl:-150.750 rpnl:26.000
# 2016-04-06 TICK ACC.NS open: 1395.0 close: 1427.699951171875
# 2016-04-06 POSITION value:1240.000 upnl:-187.700 rpnl:26.000
# 2016-04-07 TICK ACC.NS open: 1425.0 close: 1417.550048828125
# 2016-04-07 POSITION value:1240.000 upnl:-177.550 rpnl:26.000
# 2016-04-08 TICK ACC.NS open: 1414.0 close: 1441.8499755859375
# 2016-04-08 POSITION value:1240.000 upnl:-201.850 rpnl:26.000
# 2016-04-11 TICK ACC.NS open: 1447.5 close: 1447.1500244140625
# 2016-04-11 POSITION value:1240.000 upnl:-207.150 rpnl:26.000
# 2016-04-12 TICK ACC.NS open: 1448.9000244140625 close: 1448.699951171875
# 2016-04-12 POSITION value:1240.000 upnl:-208.700 rpnl:26.000
# 2016-04-13 TICK ACC.NS open: 1451.3499755859375 close: 1469.949951171875
# 2016-04-13 POSITION value:1240.000 upnl:-229.950 rpnl:26.000
# 2016-04-18 TICK ACC.NS open: 1465.0999755859375 close: 1464.1500244140625
# 2016-04-18 POSITION value:1240.000 upnl:-224.150 rpnl:26.000
# 2016-04-20 TICK ACC.NS open: 1468.0999755859375 close: 1467.6500244140625
# 2016-04-20 POSITION value:1240.000 upnl:-227.650 rpnl:26.000
# 2016-04-21 TICK ACC.NS open: 1482.5 close: 1433.300048828125
# 2016-04-21 BUY signal
# 2016-04-21 ORDER BUY ACC.NS 1
# 2016-04-21 POSITION value:1240.000 upnl:-193.300 rpnl:26.000
# 2016-04-22 TICK ACC.NS open: 1430.0 close: 1414.1500244140625
# 2016-04-22 FILLED BUY 1 ACC.NS at 1430.0
# 2016-04-22 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-04-25 TICK ACC.NS open: 1424.0 close: 1422.9000244140625
# 2016-04-25 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-04-26 TICK ACC.NS open: 1430.0 close: 1426.9000244140625
# 2016-04-26 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-04-27 TICK ACC.NS open: 1428.8499755859375 close: 1429.550048828125
# 2016-04-27 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-04-28 TICK ACC.NS open: 1422.0999755859375 close: 1437.8499755859375
# 2016-04-28 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-04-29 TICK ACC.NS open: 1450.800048828125 close: 1443.1500244140625
# 2016-04-29 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-05-02 TICK ACC.NS open: 1442.0 close: 1420.550048828125
# 2016-05-02 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-05-03 TICK ACC.NS open: 1430.0 close: 1420.1500244140625
# 2016-05-03 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-05-04 TICK ACC.NS open: 1414.0 close: 1403.699951171875
# 2016-05-04 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-05-05 TICK ACC.NS open: 1395.800048828125 close: 1394.8499755859375
# 2016-05-05 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-05-06 TICK ACC.NS open: 1389.0 close: 1425.449951171875
# 2016-05-06 SELL signal
# 2016-05-06 ORDER SELL ACC.NS 1
# 2016-05-06 POSITION value:0.000 upnl:0.000 rpnl:-190.000
# 2016-05-09 TICK ACC.NS open: 1432.5 close: 1439.75
# 2016-05-09 FILLED SELL 1 ACC.NS at 1432.5
# 2016-05-09 POSITION value:1432.500 upnl:-7.250 rpnl:-190.000
# 2016-05-10 TICK ACC.NS open: 1438.0 close: 1463.3499755859375
# 2016-05-10 POSITION value:1432.500 upnl:-30.850 rpnl:-190.000
# 2016-05-11 TICK ACC.NS open: 1457.0 close: 1467.25
# 2016-05-11 POSITION value:1432.500 upnl:-34.750 rpnl:-190.000
# 2016-05-12 TICK ACC.NS open: 1460.0 close: 1462.4000244140625
# 2016-05-12 POSITION value:1432.500 upnl:-29.900 rpnl:-190.000
# 2016-05-13 TICK ACC.NS open: 1451.0999755859375 close: 1457.0999755859375
# 2016-05-13 POSITION value:1432.500 upnl:-24.600 rpnl:-190.000
# 2016-05-16 TICK ACC.NS open: 1452.300048828125 close: 1458.199951171875
# 2016-05-16 POSITION value:1432.500 upnl:-25.700 rpnl:-190.000
# 2016-05-17 TICK ACC.NS open: 1468.0 close: 1449.4000244140625
# 2016-05-17 POSITION value:1432.500 upnl:-16.900 rpnl:-190.000
# 2016-05-18 TICK ACC.NS open: 1442.5 close: 1434.050048828125
# 2016-05-18 POSITION value:1432.500 upnl:-1.550 rpnl:-190.000
# 2016-05-19 TICK ACC.NS open: 1435.0 close: 1409.8499755859375
# 2016-05-19 BUY signal
# 2016-05-19 ORDER BUY ACC.NS 1
# 2016-05-19 POSITION value:1432.500 upnl:22.650 rpnl:-190.000
# 2016-05-20 TICK ACC.NS open: 1415.0 close: 1393.449951171875
# 2016-05-20 FILLED BUY 1 ACC.NS at 1415.0
# 2016-05-20 POSITION value:0.000 upnl:0.000 rpnl:17.500
# 2016-05-23 TICK ACC.NS open: 1393.25 close: 1418.0
# 2016-05-23 SELL signal
# 2016-05-23 ORDER SELL ACC.NS 1
# 2016-05-23 POSITION value:0.000 upnl:0.000 rpnl:17.500
# 2016-05-24 TICK ACC.NS open: 1418.050048828125 close: 1446.1500244140625
# 2016-05-24 FILLED SELL 1 ACC.NS at 1418.050048828125
# 2016-05-24 POSITION value:1418.050 upnl:-28.100 rpnl:17.500
# 2016-05-25 TICK ACC.NS open: 1456.0 close: 1475.050048828125
# 2016-05-25 POSITION value:1418.050 upnl:-57.000 rpnl:17.500
# 2016-05-26 TICK ACC.NS open: 1485.0 close: 1504.050048828125
# 2016-05-26 POSITION value:1418.050 upnl:-86.000 rpnl:17.500
# 2016-05-27 TICK ACC.NS open: 1509.0 close: 1522.949951171875
# 2016-05-27 POSITION value:1418.050 upnl:-104.900 rpnl:17.500
# 2016-05-30 TICK ACC.NS open: 1530.0 close: 1537.1500244140625
# 2016-05-30 POSITION value:1418.050 upnl:-119.100 rpnl:17.500
# 2016-05-31 TICK ACC.NS open: 1535.050048828125 close: 1529.050048828125
# 2016-05-31 POSITION value:1418.050 upnl:-111.000 rpnl:17.500
# 2016-06-01 TICK ACC.NS open: 1535.0 close: 1552.4000244140625
# 2016-06-01 POSITION value:1418.050 upnl:-134.350 rpnl:17.500
# 2016-06-02 TICK ACC.NS open: 1552.4000244140625 close: 1546.300048828125
# 2016-06-02 POSITION value:1418.050 upnl:-128.250 rpnl:17.500
# 2016-06-03 TICK ACC.NS open: 1553.5 close: 1540.0
# 2016-06-03 POSITION value:1418.050 upnl:-121.950 rpnl:17.500
# 2016-06-06 TICK ACC.NS open: 1542.0 close: 1534.699951171875
# 2016-06-06 POSITION value:1418.050 upnl:-116.650 rpnl:17.500
# 2016-06-07 TICK ACC.NS open: 1526.1500244140625 close: 1540.449951171875
# 2016-06-07 POSITION value:1418.050 upnl:-122.400 rpnl:17.500
# 2016-06-08 TICK ACC.NS open: 1545.0 close: 1546.75
# 2016-06-08 POSITION value:1418.050 upnl:-128.700 rpnl:17.500
# 2016-06-09 TICK ACC.NS open: 1547.5 close: 1533.0
# 2016-06-09 POSITION value:1418.050 upnl:-114.950 rpnl:17.500
# 2016-06-10 TICK ACC.NS open: 1530.0 close: 1555.6500244140625
# 2016-06-10 POSITION value:1418.050 upnl:-137.600 rpnl:17.500
# 2016-06-13 TICK ACC.NS open: 1548.0 close: 1546.800048828125
# 2016-06-13 POSITION value:1418.050 upnl:-128.750 rpnl:17.500
# 2016-06-14 TICK ACC.NS open: 1550.0 close: 1539.949951171875
# 2016-06-14 POSITION value:1418.050 upnl:-121.900 rpnl:17.500
# 2016-06-15 TICK ACC.NS open: 1542.050048828125 close: 1560.1500244140625
# 2016-06-15 POSITION value:1418.050 upnl:-142.100 rpnl:17.500
# 2016-06-16 TICK ACC.NS open: 1559.9000244140625 close: 1544.949951171875
# 2016-06-16 POSITION value:1418.050 upnl:-126.900 rpnl:17.500
# 2016-06-17 TICK ACC.NS open: 1555.0 close: 1555.4000244140625
# 2016-06-17 POSITION value:1418.050 upnl:-137.350 rpnl:17.500
# 2016-06-20 TICK ACC.NS open: 1538.4000244140625 close: 1570.1500244140625
# 2016-06-20 POSITION value:1418.050 upnl:-152.100 rpnl:17.500
# 2016-06-21 TICK ACC.NS open: 1573.0 close: 1559.0
# 2016-06-21 POSITION value:1418.050 upnl:-140.950 rpnl:17.500
# 2016-06-22 TICK ACC.NS open: 1565.0 close: 1571.050048828125
# 2016-06-22 POSITION value:1418.050 upnl:-153.000 rpnl:17.500
# 2016-06-23 TICK ACC.NS open: 1571.0 close: 1571.5999755859375
# 2016-06-23 POSITION value:1418.050 upnl:-153.550 rpnl:17.500
# 2016-06-24 TICK ACC.NS open: 1550.0 close: 1568.0999755859375
# 2016-06-24 POSITION value:1418.050 upnl:-150.050 rpnl:17.500
# 2016-06-27 TICK ACC.NS open: 1567.0 close: 1601.0
# 2016-06-27 POSITION value:1418.050 upnl:-182.950 rpnl:17.500
# 2016-06-28 TICK ACC.NS open: 1608.199951171875 close: 1598.4000244140625
# 2016-06-28 POSITION value:1418.050 upnl:-180.350 rpnl:17.500
# 2016-06-29 TICK ACC.NS open: 1617.0 close: 1598.949951171875
# 2016-06-29 POSITION value:1418.050 upnl:-180.900 rpnl:17.500
# 2016-06-30 TICK ACC.NS open: 1601.5 close: 1616.050048828125
# 2016-06-30 POSITION value:1418.050 upnl:-198.000 rpnl:17.500
# 2016-07-01 TICK ACC.NS open: 1618.3499755859375 close: 1617.4000244140625
# 2016-07-01 POSITION value:1418.050 upnl:-199.350 rpnl:17.500
# 2016-07-04 TICK ACC.NS open: 1618.0 close: 1605.5999755859375
# 2016-07-04 POSITION value:1418.050 upnl:-187.550 rpnl:17.500
# 2016-07-05 TICK ACC.NS open: 1612.699951171875 close: 1589.300048828125
# 2016-07-05 POSITION value:1418.050 upnl:-171.250 rpnl:17.500
# 2016-07-07 TICK ACC.NS open: 1585.699951171875 close: 1604.699951171875
# 2016-07-07 POSITION value:1418.050 upnl:-186.650 rpnl:17.500
# ...
# 2017-07-12 TICK ACC.NS open: 1700.0 close: 1705.949951171875
# 2017-07-12 SELL signal
# 2017-07-12 ORDER SELL ACC.NS 1
# 2017-07-12 POSITION value:-1635.000 upnl:70.950 rpnl:92.050
# 2017-07-13 TICK ACC.NS open: 1707.25 close: 1703.550048828125
# 2017-07-13 FILLED SELL 1 ACC.NS at 1707.25
# 2017-07-13 POSITION value:0.000 upnl:0.000 rpnl:72.250
# 2017-07-14 TICK ACC.NS open: 1701.0 close: 1755.0999755859375
# 2017-07-14 SELL signal
# 2017-07-14 ORDER SELL ACC.NS 1
# 2017-07-14 POSITION value:0.000 upnl:0.000 rpnl:72.250
# 2017-07-17 TICK ACC.NS open: 1761.0 close: 1747.4000244140625
# 2017-07-17 FILLED SELL 1 ACC.NS at 1761.0
# 2017-07-17 POSITION value:1761.000 upnl:13.600 rpnl:72.250
# 2017-07-18 TICK ACC.NS open: 1800.0 close: 1759.5
# 2017-07-18 POSITION value:1761.000 upnl:1.500 rpnl:72.250
# 2017-07-19 TICK ACC.NS open: 1767.8499755859375 close: 1734.5999755859375
# 2017-07-19 POSITION value:1761.000 upnl:26.400 rpnl:72.250
# 2017-07-20 TICK ACC.NS open: 1742.949951171875 close: 1712.0
# 2017-07-20 POSITION value:1761.000 upnl:49.000 rpnl:72.250
# 2017-07-21 TICK ACC.NS open: 1718.0 close: 1708.5999755859375
# 2017-07-21 POSITION value:1761.000 upnl:52.400 rpnl:72.250
# 2017-07-24 TICK ACC.NS open: 1715.0 close: 1724.8499755859375
# 2017-07-24 POSITION value:1761.000 upnl:36.150 rpnl:72.250
# 2017-07-25 TICK ACC.NS open: 1747.5 close: 1726.0999755859375
# 2017-07-25 POSITION value:1761.000 upnl:34.900 rpnl:72.250
# 2017-07-26 TICK ACC.NS open: 1725.0 close: 1706.3499755859375
# 2017-07-26 POSITION value:1761.000 upnl:54.650 rpnl:72.250
# 2017-07-27 TICK ACC.NS open: 1712.0 close: 1732.0
# 2017-07-27 POSITION value:1761.000 upnl:29.000 rpnl:72.250
# 2017-07-28 TICK ACC.NS open: 1738.800048828125 close: 1731.199951171875
# 2017-07-28 POSITION value:1761.000 upnl:29.800 rpnl:72.250
# 2017-07-31 TICK ACC.NS open: 1736.0 close: 1733.199951171875
# 2017-07-31 POSITION value:1761.000 upnl:27.800 rpnl:72.250
# 2017-08-01 TICK ACC.NS open: 1743.0 close: 1737.75
# 2017-08-01 POSITION value:1761.000 upnl:23.250 rpnl:72.250
# 2017-08-02 TICK ACC.NS open: 1725.0 close: 1772.0999755859375
# 2017-08-02 POSITION value:1761.000 upnl:-11.100 rpnl:72.250
# 2017-08-03 TICK ACC.NS open: 1778.0 close: 1810.5999755859375
# 2017-08-03 POSITION value:1761.000 upnl:-49.600 rpnl:72.250
# 2017-08-04 TICK ACC.NS open: 1793.5 close: 1813.3499755859375
# 2017-08-04 POSITION value:1761.000 upnl:-52.350 rpnl:72.250
# 2017-08-07 TICK ACC.NS open: 1818.0 close: 1817.3499755859375
# 2017-08-07 POSITION value:1761.000 upnl:-56.350 rpnl:72.250
# 2017-08-08 TICK ACC.NS open: 1817.3499755859375 close: 1812.1500244140625
# 2017-08-08 POSITION value:1761.000 upnl:-51.150 rpnl:72.250
# 2017-08-09 TICK ACC.NS open: 1809.949951171875 close: 1819.5
# 2017-08-09 POSITION value:1761.000 upnl:-58.500 rpnl:72.250
# 2017-08-10 TICK ACC.NS open: 1813.9000244140625 close: 1776.699951171875
# 2017-08-10 BUY signal
# 2017-08-10 ORDER BUY ACC.NS 1
# 2017-08-10 POSITION value:1761.000 upnl:-15.700 rpnl:72.250
# 2017-08-11 TICK ACC.NS open: 1764.9000244140625 close: 1760.550048828125
# 2017-08-11 FILLED BUY 1 ACC.NS at 1764.9000244140625
# 2017-08-11 POSITION value:0.000 upnl:0.000 rpnl:-3.900
# 2017-08-14 TICK ACC.NS open: 1764.800048828125 close: 1784.800048828125
# 2017-08-14 POSITION value:0.000 upnl:0.000 rpnl:-3.900
# 2017-08-16 TICK ACC.NS open: 1785.5999755859375 close: 1811.199951171875
# 2017-08-16 POSITION value:0.000 upnl:0.000 rpnl:-3.900
# 2017-08-17 TICK ACC.NS open: 1814.0 close: 1780.0999755859375
# 2017-08-17 BUY signal
# 2017-08-17 ORDER BUY ACC.NS 1
# 2017-08-17 POSITION value:0.000 upnl:0.000 rpnl:-3.900
# 2017-08-18 TICK ACC.NS open: 1773.5999755859375 close: 1794.300048828125
# 2017-08-18 FILLED BUY 1 ACC.NS at 1773.5999755859375
# 2017-08-18 POSITION value:-1773.600 upnl:20.700 rpnl:-3.900
# 2017-08-21 TICK ACC.NS open: 1809.0 close: 1792.5999755859375
# 2017-08-21 POSITION value:-1773.600 upnl:19.000 rpnl:-3.900
# 2017-08-22 TICK ACC.NS open: 1798.9000244140625 close: 1789.300048828125
# 2017-08-22 POSITION value:-1773.600 upnl:15.700 rpnl:-3.900
# 2017-08-23 TICK ACC.NS open: 1787.0 close: 1801.9000244140625
# 2017-08-23 POSITION value:-1773.600 upnl:28.300 rpnl:-3.900
# 2017-08-24 TICK ACC.NS open: 1794.0 close: 1781.5
# 2017-08-24 POSITION value:-1773.600 upnl:7.900 rpnl:-3.900
# 2017-08-28 TICK ACC.NS open: 1784.4000244140625 close: 1815.699951171875
# 2017-08-28 POSITION value:-1773.600 upnl:42.100 rpnl:-3.900
# 2017-08-29 TICK ACC.NS open: 1800.0 close: 1801.5
# 2017-08-29 POSITION value:-1773.600 upnl:27.900 rpnl:-3.900
# 2017-08-30 TICK ACC.NS open: 1819.0 close: 1811.199951171875
# 2017-08-30 POSITION value:-1773.600 upnl:37.600 rpnl:-3.900
# 2017-08-31 TICK ACC.NS open: 1814.0 close: 1800.25
# 2017-08-31 POSITION value:-1773.600 upnl:26.650 rpnl:-3.900
# 2017-09-01 TICK ACC.NS open: 1794.0 close: 1818.050048828125
# 2017-09-01 POSITION value:-1773.600 upnl:44.450 rpnl:-3.900
# 2017-09-04 TICK ACC.NS open: 1823.699951171875 close: 1771.0999755859375
# 2017-09-04 POSITION value:-1773.600 upnl:-2.500 rpnl:-3.900
# 2017-09-05 TICK ACC.NS open: 1772.4000244140625 close: 1804.949951171875
# 2017-09-05 POSITION value:-1773.600 upnl:31.350 rpnl:-3.900
# 2017-09-06 TICK ACC.NS open: 1799.0 close: 1807.0999755859375
# 2017-09-06 POSITION value:-1773.600 upnl:33.500 rpnl:-3.900
# 2017-09-07 TICK ACC.NS open: 1806.800048828125 close: 1786.75
# 2017-09-07 POSITION value:-1773.600 upnl:13.150 rpnl:-3.900
# 2017-09-08 TICK ACC.NS open: 1793.4000244140625 close: 1791.25
# 2017-09-08 POSITION value:-1773.600 upnl:17.650 rpnl:-3.900
# 2017-09-11 TICK ACC.NS open: 1803.3499755859375 close: 1797.550048828125
# 2017-09-11 POSITION value:-1773.600 upnl:23.950 rpnl:-3.900
# 2017-09-12 TICK ACC.NS open: 1797.550048828125 close: 1851.25
# 2017-09-12 SELL signal
# 2017-09-12 ORDER SELL ACC.NS 1
# 2017-09-12 POSITION value:-1773.600 upnl:77.650 rpnl:-3.900
# 2017-09-13 TICK ACC.NS open: 1848.0 close: 1843.75
# 2017-09-13 FILLED SELL 1 ACC.NS at 1848.0
# 2017-09-13 POSITION value:0.000 upnl:0.000 rpnl:74.400
# 2017-09-14 TICK ACC.NS open: 1841.0 close: 1844.8499755859375
# 2017-09-14 POSITION value:0.000 upnl:0.000 rpnl:74.400
# 2017-09-15 TICK ACC.NS open: 1840.0 close: 1820.699951171875
# 2017-09-15 POSITION value:0.000 upnl:0.000 rpnl:74.400
# 2017-09-18 TICK ACC.NS open: 1827.199951171875 close: 1825.8499755859375
# 2017-09-18 POSITION value:0.000 upnl:0.000 rpnl:74.400
# 2017-09-19 TICK ACC.NS open: 1832.699951171875 close: 1817.199951171875
# 2017-09-19 POSITION value:0.000 upnl:0.000 rpnl:74.400
# 2017-09-20 TICK ACC.NS open: 1823.0 close: 1786.050048828125
# 2017-09-20 POSITION value:0.000 upnl:0.000 rpnl:74.400
# 2017-09-21 TICK ACC.NS open: 1786.949951171875 close: 1749.800048828125
# 2017-09-21 POSITION value:0.000 upnl:0.000 rpnl:74.400
# 2017-09-22 TICK ACC.NS open: 1745.25 close: 1688.300048828125
# 2017-09-22 BUY signal
# 2017-09-22 ORDER BUY ACC.NS 1
# 2017-09-22 POSITION value:0.000 upnl:0.000 rpnl:74.400
# 2017-09-25 TICK ACC.NS open: 1688.0 close: 1632.6500244140625
# 2017-09-25 FILLED BUY 1 ACC.NS at 1688.0
# 2017-09-25 POSITION value:-1688.000 upnl:-55.350 rpnl:74.400
# 2017-09-26 TICK ACC.NS open: 1628.0 close: 1632.0999755859375
# 2017-09-26 POSITION value:-1688.000 upnl:-55.900 rpnl:74.400
# 2017-09-27 TICK ACC.NS open: 1644.0 close: 1589.75
# 2017-09-27 POSITION value:-1688.000 upnl:-98.250 rpnl:74.400
# 2017-09-28 TICK ACC.NS open: 1596.0 close: 1645.8499755859375
# 2017-09-28 SELL signal
# 2017-09-28 ORDER SELL ACC.NS 1
# 2017-09-28 POSITION value:-1688.000 upnl:-42.150 rpnl:74.400
# 2017-09-29 TICK ACC.NS open: 1660.0 close: 1656.9000244140625
# 2017-09-29 FILLED SELL 1 ACC.NS at 1660.0
# 2017-09-29 POSITION value:0.000 upnl:0.000 rpnl:-28.000
# 2017-10-03 TICK ACC.NS open: 1670.0999755859375 close: 1647.1500244140625
# 2017-10-03 POSITION value:0.000 upnl:0.000 rpnl:-28.000
# 2017-10-04 TICK ACC.NS open: 1650.0 close: 1651.050048828125
# 2017-10-04 POSITION value:0.000 upnl:0.000 rpnl:-28.000
# 2017-10-05 TICK ACC.NS open: 1653.800048828125 close: 1700.1500244140625
# 2017-10-05 SELL signal
# 2017-10-05 ORDER SELL ACC.NS 1
# 2017-10-05 POSITION value:0.000 upnl:0.000 rpnl:-28.000
# 2017-10-06 TICK ACC.NS open: 1704.949951171875 close: 1739.5999755859375
# 2017-10-06 FILLED SELL 1 ACC.NS at 1704.949951171875
# 2017-10-06 POSITION value:1704.950 upnl:-34.650 rpnl:-28.000
# 2017-10-09 TICK ACC.NS open: 1740.0 close: 1728.1500244140625
# 2017-10-09 POSITION value:1704.950 upnl:-23.200 rpnl:-28.000
# 2017-10-10 TICK ACC.NS open: 1726.0 close: 1734.050048828125
# 2017-10-10 POSITION value:1704.950 upnl:-29.100 rpnl:-28.000
# 2017-10-11 TICK ACC.NS open: 1745.0 close: 1715.449951171875
# 2017-10-11 POSITION value:1704.950 upnl:-10.500 rpnl:-28.000
# 2017-10-12 TICK ACC.NS open: 1719.199951171875 close: 1741.050048828125
# 2017-10-12 POSITION value:1704.950 upnl:-36.100 rpnl:-28.000
# 2017-10-13 TICK ACC.NS open: 1745.0 close: 1770.050048828125
# 2017-10-13 POSITION value:1704.950 upnl:-65.100 rpnl:-28.000
# 2017-10-16 TICK ACC.NS open: 1776.0 close: 1789.699951171875
# 2017-10-16 POSITION value:1704.950 upnl:-84.750 rpnl:-28.000
# 2017-10-17 TICK ACC.NS open: 1790.0 close: 1792.5
# 2017-10-17 POSITION value:1704.950 upnl:-87.550 rpnl:-28.000
# 2017-10-18 TICK ACC.NS open: 1810.0 close: 1783.75
# 2017-10-18 POSITION value:1704.950 upnl:-78.800 rpnl:-28.000
# 2017-10-19 TICK ACC.NS open: 1785.0 close: 1765.1500244140625
# 2017-10-19 POSITION value:1704.950 upnl:-60.200 rpnl:-28.000
# 2017-10-23 TICK ACC.NS open: 1770.300048828125 close: 1781.0
# 2017-10-23 POSITION value:1704.950 upnl:-76.050 rpnl:-28.000
# 2017-10-24 TICK ACC.NS open: 1792.0 close: 1777.699951171875
# 2017-10-24 POSITION value:1704.950 upnl:-72.750 rpnl:-28.000
# 2017-10-25 TICK ACC.NS open: 1785.050048828125 close: 1801.199951171875
# 2017-10-25 POSITION value:1704.950 upnl:-96.250 rpnl:-28.000
# 2017-10-26 TICK ACC.NS open: 1803.699951171875 close: 1782.449951171875
# 2017-10-26 POSITION value:1704.950 upnl:-77.500 rpnl:-28.000
# 2017-10-27 TICK ACC.NS open: 1785.949951171875 close: 1783.1500244140625
# 2017-10-27 POSITION value:1704.950 upnl:-78.200 rpnl:-28.000
# 2017-10-30 TICK ACC.NS open: 1795.0 close: 1819.550048828125
# 2017-10-30 POSITION value:1704.950 upnl:-114.600 rpnl:-28.000
# 2017-10-31 TICK ACC.NS open: 1821.0 close: 1809.5
# 2017-10-31 POSITION value:1704.950 upnl:-104.550 rpnl:-28.000
# 2017-11-01 TICK ACC.NS open: 1815.0 close: 1823.3499755859375
# 2017-11-01 POSITION value:1704.950 upnl:-118.400 rpnl:-28.000
# 2017-11-02 TICK ACC.NS open: 1832.6500244140625 close: 1799.4000244140625
# 2017-11-02 POSITION value:1704.950 upnl:-94.450 rpnl:-28.000
# 2017-11-03 TICK ACC.NS open: 1805.0999755859375 close: 1805.199951171875
# 2017-11-03 POSITION value:1704.950 upnl:-100.250 rpnl:-28.000
# 2017-11-06 TICK ACC.NS open: 1801.0 close: 1803.699951171875
# 2017-11-06 POSITION value:1704.950 upnl:-98.750 rpnl:-28.000
# 2017-11-07 TICK ACC.NS open: 1809.8499755859375 close: 1790.0
# 2017-11-07 POSITION value:1704.950 upnl:-85.050 rpnl:-28.000
# 2017-11-08 TICK ACC.NS open: 1798.9000244140625 close: 1787.800048828125
# 2017-11-08 POSITION value:1704.950 upnl:-82.850 rpnl:-28.000
# 2017-11-09 TICK ACC.NS open: 1787.0 close: 1760.5999755859375
# 2017-11-09 BUY signal
# 2017-11-09 ORDER BUY ACC.NS 1
# 2017-11-09 POSITION value:1704.950 upnl:-55.650 rpnl:-28.000
# 2017-11-10 TICK ACC.NS open: 1754.8499755859375 close: 1754.300048828125
# 2017-11-10 FILLED BUY 1 ACC.NS at 1754.8499755859375
# 2017-11-10 POSITION value:0.000 upnl:0.000 rpnl:-49.900
# 2017-11-13 TICK ACC.NS open: 1750.0 close: 1756.75
# 2017-11-13 POSITION value:0.000 upnl:0.000 rpnl:-49.900
# 2017-11-14 TICK ACC.NS open: 1756.75 close: 1743.050048828125
# 2017-11-14 POSITION value:0.000 upnl:0.000 rpnl:-49.900
# 2017-11-15 TICK ACC.NS open: 1739.0 close: 1770.8499755859375
# 2017-11-15 SELL signal
# 2017-11-15 ORDER SELL ACC.NS 1
# 2017-11-15 POSITION value:0.000 upnl:0.000 rpnl:-49.900
# 2017-11-16 TICK ACC.NS open: 1778.0 close: 1795.6500244140625
# 2017-11-16 FILLED SELL 1 ACC.NS at 1778.0
# 2017-11-16 POSITION value:1778.000 upnl:-17.650 rpnl:-49.900
# 2017-11-17 TICK ACC.NS open: 1803.800048828125 close: 1763.050048828125
# 2017-11-17 BUY signal
# 2017-11-17 ORDER BUY ACC.NS 1
# 2017-11-17 POSITION value:1778.000 upnl:14.950 rpnl:-49.900
# 2017-11-20 TICK ACC.NS open: 1745.550048828125 close: 1707.050048828125
# 2017-11-20 FILLED BUY 1 ACC.NS at 1745.550048828125
# 2017-11-20 BUY signal
# 2017-11-20 ORDER BUY ACC.NS 1
# 2017-11-20 POSITION value:0.000 upnl:0.000 rpnl:32.450
# 2017-11-21 TICK ACC.NS open: 1709.5999755859375 close: 1705.300048828125
# 2017-11-21 FILLED BUY 1 ACC.NS at 1709.5999755859375
# 2017-11-21 POSITION value:-1709.600 upnl:-4.300 rpnl:32.450
# 2017-11-22 TICK ACC.NS open: 1710.0 close: 1722.25
# 2017-11-22 POSITION value:-1709.600 upnl:12.650 rpnl:32.450
# 2017-11-23 TICK ACC.NS open: 1728.0 close: 1712.25
# 2017-11-23 POSITION value:-1709.600 upnl:2.650 rpnl:32.450
# 2017-11-24 TICK ACC.NS open: 1715.0 close: 1697.699951171875
# 2017-11-24 POSITION value:-1709.600 upnl:-11.900 rpnl:32.450
# 2017-11-27 TICK ACC.NS open: 1694.8499755859375 close: 1693.300048828125
# 2017-11-27 POSITION value:-1709.600 upnl:-16.300 rpnl:32.450
# 2017-11-28 TICK ACC.NS open: 1699.0 close: 1681.25
# 2017-11-28 POSITION value:-1709.600 upnl:-28.350 rpnl:32.450
# 2017-11-29 TICK ACC.NS open: 1680.9000244140625 close: 1682.5
# 2017-11-29 POSITION value:-1709.600 upnl:-27.100 rpnl:32.450
# 2017-11-30 TICK ACC.NS open: 1674.0999755859375 close: 1667.9000244140625
# 2017-11-30 POSITION value:-1709.600 upnl:-41.700 rpnl:32.450
# 2017-12-01 TICK ACC.NS open: 1672.4000244140625 close: 1676.6500244140625
# 2017-12-01 POSITION value:-1709.600 upnl:-32.950 rpnl:32.450
# 2017-12-04 TICK ACC.NS open: 1680.0 close: 1694.050048828125
# 2017-12-04 POSITION value:-1709.600 upnl:-15.550 rpnl:32.450
# 2017-12-05 TICK ACC.NS open: 1693.0 close: 1698.199951171875
# 2017-12-05 POSITION value:-1709.600 upnl:-11.400 rpnl:32.450
# 2017-12-06 TICK ACC.NS open: 1692.0 close: 1690.0999755859375
# 2017-12-06 POSITION value:-1709.600 upnl:-19.500 rpnl:32.450
# 2017-12-07 TICK ACC.NS open: 1688.0999755859375 close: 1703.449951171875
# 2017-12-07 POSITION value:-1709.600 upnl:-6.150 rpnl:32.450
# 2017-12-08 TICK ACC.NS open: 1708.0 close: 1746.949951171875
# 2017-12-08 SELL signal
# 2017-12-08 ORDER SELL ACC.NS 1
# 2017-12-08 POSITION value:-1709.600 upnl:37.350 rpnl:32.450
# 2017-12-11 TICK ACC.NS open: 1751.0999755859375 close: 1732.800048828125
# 2017-12-11 FILLED SELL 1 ACC.NS at 1751.0999755859375
# 2017-12-11 POSITION value:0.000 upnl:0.000 rpnl:41.500
# 2017-12-12 TICK ACC.NS open: 1735.0 close: 1710.25
# 2017-12-12 POSITION value:0.000 upnl:0.000 rpnl:41.500
# 2017-12-13 TICK ACC.NS open: 1707.5 close: 1706.0
# 2017-12-13 POSITION value:0.000 upnl:0.000 rpnl:41.500
# 2017-12-14 TICK ACC.NS open: 1714.4000244140625 close: 1688.199951171875
# 2017-12-14 POSITION value:0.000 upnl:0.000 rpnl:41.500
# 2017-12-15 TICK ACC.NS open: 1704.8499755859375 close: 1696.5
# 2017-12-15 POSITION value:0.000 upnl:0.000 rpnl:41.500
# 2017-12-18 TICK ACC.NS open: 1687.5999755859375 close: 1696.8499755859375
# 2017-12-18 POSITION value:0.000 upnl:0.000 rpnl:41.500
# 2017-12-19 TICK ACC.NS open: 1704.800048828125 close: 1730.300048828125
# 2017-12-19 SELL signal
# 2017-12-19 ORDER SELL ACC.NS 1
# 2017-12-19 POSITION value:0.000 upnl:0.000 rpnl:41.500
# 2017-12-20 TICK ACC.NS open: 1726.0 close: 1727.199951171875
# 2017-12-20 FILLED SELL 1 ACC.NS at 1726.0
# 2017-12-20 POSITION value:1726.000 upnl:-1.200 rpnl:41.500
# 2017-12-21 TICK ACC.NS open: 1718.050048828125 close: 1738.8499755859375
# 2017-12-21 POSITION value:1726.000 upnl:-12.850 rpnl:41.500
# 2017-12-22 TICK ACC.NS open: 1748.0 close: 1721.6500244140625
# 2017-12-22 POSITION value:1726.000 upnl:4.350 rpnl:41.500
# 2017-12-26 TICK ACC.NS open: 1721.6500244140625 close: 1742.0999755859375
# 2017-12-26 POSITION value:1726.000 upnl:-16.100 rpnl:41.500
# 2017-12-27 TICK ACC.NS open: 1740.1500244140625 close: 1735.800048828125
# 2017-12-27 POSITION value:1726.000 upnl:-9.800 rpnl:41.500
# 2017-12-28 TICK ACC.NS open: 1737.0 close: 1748.6500244140625
# 2017-12-28 POSITION value:1726.000 upnl:-22.650 rpnl:41.500
# 2017-12-29 TICK ACC.NS open: 1754.9000244140625 close: 1758.4000244140625
# 2017-12-29 POSITION value:1726.000 upnl:-32.400 rpnl:41.500
# Backtest completed.
